# %% [markdown]
# ### Importing Libraries

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn
from sklearn import preprocessing

# %% [markdown]
# ### Displaying the version of Libraries used

# %%
# Python version
print('Python: {}'.format(sys.version))
# pandas
print('pandas: {}'.format(pd.__version__))
# numpy
print('numpy: {}'.format(np.__version__))
# seaborn
print('seaborn: {}'.format(sns.__version__))
# scikit-learn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.9.5 (tags/v3.9.5:0a7dcbd, May  3 2021, 17:27:52) [MSC v.1928 64 bit (AMD64)]
# pandas: 1.4.1
# numpy: 1.22.2
# seaborn: 0.11.2
# sklearn: 1.0.2

# %% [markdown]
# # Data = DOAC2022.xlsx

# %% [markdown]
# ### Reading data from csv file

# %%
data = pd.read_excel("DOAC2022.xlsx")

# %%
data.head()
# Out:
#    MRN     Ethnic Group  PersonSK  EncounterSK Length Of Stay    EventSk  \
# 0   96  White - British   5859512     39337940              9  832948603
# 1   96  White - British   5859512     39337940              9  834980349
# 2   96  White - British   5859512     39337940              9  837113509
# 3   96  White - British   5859512     39337940              9  838714390
# 4   96  White - British   5859512     39337940              9  840199866
#
#    Age at Given Date    EventType      AC AddedTo EPR AC Stated PerformedTime  \
# 0                 71  Rivaroxaban 2018-10-03 17:31:09     2018-10-03 17:25:00
# 1                 71  Rivaroxaban 2018-10-04 16:36:44     2018-10-04 16:36:00
# 2                 71  Rivaroxaban 2018-10-05 17:10:49     2018-10-05 17:10:00
# 3                 71  Rivaroxaban 2018-10-06 16:58:47     2018-10-06 16:58:00
# 4                 71  Rivaroxaban 2018-10-07 17:17:19     2018-10-07 17:17:00
#
#    ... Emergency Admissions Upto 36 Months After PerformedTime  \
# 0  ...                                                  3
# 1  ...                                                  3
# 2  ...                                                  3
# 3  ...                                                  3
# 4  ...                                                  3
#
#   Mat Admissions Within 3 Years            Admit Method  \
# 0                             0  Accident and Emergency
# 1                             0  Accident and Emergency
# 2                             0  Accident and Emergency
# 3                             0  Accident and Emergency
# 4                             0  Accident and Emergency
#
#    Has Comorbidity Recorded on Spell Has Bleeding Event (or Stroke) on Spell  \
# 0                                Yes                                      No
# 1                                Yes                                      No
# 2                                Yes                                      No
# 3                                Yes                                      No
# 4                                Yes                                      No
#
#   Has Stroke on Spell Has Thrombosis on Spell Treatment_days AC_END_DATE  \
# 0                  No                      No         1117.0  2021-10-24
# 1                  No                      No         1116.0  2021-10-24
# 2                  No                      No         1115.0  2021-10-24
# 3                  No                      No         1114.0  2021-10-24
# 4                  No                      No         1113.0  2021-10-24
#
#   AC_START_DATE
# 0     3/10/2018
# 1     4/10/2018
# 2     5/10/2018
# 3     6/10/2018
# 4     7/10/2018
#
# [5 rows x 50 columns]

# %%
print("Shape of data: ", data.shape)
print(data.columns)
# Out:
# Shape of data:  (183552, 50)
# Index(['MRN', 'Ethnic Group', 'PersonSK', 'EncounterSK', 'Length Of Stay',
#        'EventSk', 'Age at Given Date', 'EventType', 'AC AddedTo EPR',
#        'AC Stated PerformedTime', 'AC Stated Performed Date',
#        'AC Stated Performed Week', 'AC Stated Performed Month', 'AC Amount',
#        'AC untits', 'EGFR Type', 'EGFR Stated Date', 'EGFR Result 60 Or Less',
#        'EGFR Result', 'EGFR Units', 'Gender', 'Date Of Death',
#        'Deceased in EPR', 'Clinical Display', 'Bleeding Risk',
#        'Bleeding Risk Time', 'VTE Risk', 'VTE Risk Time', 'Height',
#        'Height Time', 'Weight', 'Weight Time', 'Calculated BMI', 'Actual BMI',
#        'Actual BMI Time', 'BMI Type', 'BMI Result', 'BMI Stated Date',
#        'BMI Flag', 'Difference in BMIs',
#        'Emergency Admissions Upto 36 Months After PerformedTime',
#        'Mat Admissions Within 3 Years', 'Admit Method',
#        'Has Comorbidity Recorded on Spell',
#        'Has Bleeding Event (or Stroke) on Spell', 'Has Stroke on Spell',
#        'Has Thrombosis on Spell', 'Treatment_days', 'AC_END_DATE',
#        'AC_START_DATE'],
#       dtype='object')

# %% [markdown]
# ## Droping irrelevant columns

# %%
data = data.drop(['AC AddedTo EPR','AC Stated PerformedTime','AC Stated Performed Date','AC Stated Performed Week',
                 'AC Stated Performed Month','AC untits','EGFR Type','EGFR Stated Date','EGFR Units',
                 'Bleeding Risk Time','VTE Risk Time','Height Time', 'Weight Time',
                 'Actual BMI Time','BMI Type', 'BMI Result', 'BMI Stated Date', 'Difference in BMIs',
                 'Mat Admissions Within 3 Years', 'Admit Method','AC_END_DATE' ,'AC_START_DATE'],axis=1)

# %%
print("Shape of data: ", data.shape)
print(data.columns)
# Out:
# Shape of data:  (183552, 28)
# Index(['MRN', 'Ethnic Group', 'PersonSK', 'EncounterSK', 'Length Of Stay',
#        'EventSk', 'Age at Given Date', 'EventType', 'AC Amount',
#        'EGFR Result 60 Or Less', 'EGFR Result', 'Gender', 'Date Of Death',
#        'Deceased in EPR', 'Clinical Display', 'Bleeding Risk', 'VTE Risk',
#        'Height', 'Weight', 'Calculated BMI', 'Actual BMI', 'BMI Flag',
#        'Emergency Admissions Upto 36 Months After PerformedTime',
#        'Has Comorbidity Recorded on Spell',
#        'Has Bleeding Event (or Stroke) on Spell', 'Has Stroke on Spell',
#        'Has Thrombosis on Spell', 'Treatment_days'],
#       dtype='object')

# %% [markdown]
# ## 1- Replacing "-" with N/A

# %%
data = data.replace("-", "")

# %% [markdown]
# ## 1.1- Missing values

# %%
data.isnull( ).sum( )
# Out:
# MRN                                                            0
# Ethnic Group                                                   0
# PersonSK                                                       0
# EncounterSK                                                    0
# Length Of Stay                                               971
# EventSk                                                        0
# Age at Given Date                                              0
# EventType                                                      0
# AC Amount                                                      4
# EGFR Result 60 Or Less                                         0
# EGFR Result                                                 2613
# Gender                                                         0
# Date Of Death                                                  0
# Deceased in EPR                                                0
# Clinical Display                                               1
# Bleeding Risk                                               3919
# VTE Risk                                                    3867
# Height                                                     54351
# Weight                                                     47908
# Calculated BMI                                             62037
# Actual BMI                                                 67282
# BMI Flag                                                       0
# Emergency Admissions Upto 36 Months After PerformedTime        0
# Has Comorbidity Recorded on Spell                              0
# Has Bleeding Event (or Stroke) on Spell                        0
# Has Stroke on Spell                                            0
# Has Thrombosis on Spell                                        0
# Treatment_days                                             17544
# dtype: int64

# %% [markdown]
# ## 2- Lower case String(Object) columns of the dataFrame

# %%
data["Ethnic Group"] = data["Ethnic Group"].str.lower()
data["EventType"] = data["EventType"].str.lower()
#data["AC untits"] = data["AC untits"].str.lower()
#data["EGFR Type"] = data["EGFR Type"].str.lower()
data["EGFR Result 60 Or Less"] = data["EGFR Result 60 Or Less"].str.lower()
#data["EGFR Units"] = data["EGFR Units"].str.lower()
data["Gender"] = data["Gender"].str.lower()
data["Deceased in EPR"] = data["Deceased in EPR"].str.lower()
data["Bleeding Risk"] = data["Bleeding Risk"].str.lower()
data["VTE Risk"] = data["VTE Risk"].str.lower()
#data["BMI Type"] = data["BMI Type"].str.lower()
#data["BMI Result"] = data["BMI Result"].str.lower()
data["BMI Flag"] = data["BMI Flag"].str.lower()
#data["Admit Method"] = data["Admit Method"].str.lower()
data["Has Comorbidity Recorded on Spell"] = data["Has Comorbidity Recorded on Spell"].str.lower()
data["Has Bleeding Event (or Stroke) on Spell"] = data["Has Bleeding Event (or Stroke) on Spell"].str.lower()
data["Has Stroke on Spell"] = data["Has Stroke on Spell"].str.lower()
data["Has Thrombosis on Spell"] = data["Has Thrombosis on Spell"].str.lower()

# %%
data.dtypes
# Out:
# MRN                                                          int64
# Ethnic Group                                                object
# PersonSK                                                     int64
# EncounterSK                                                  int64
# Length Of Stay                                              object
# EventSk                                                      int64
# Age at Given Date                                            int64
# EventType                                                   object
# AC Amount                                                  float64
# EGFR Result 60 Or Less                                      object
# EGFR Result                                                 object
# Gender                                                      object
# Date Of Death                                               object
# Deceased in EPR                                             object
# Clinical Display                                            object
# Bleeding Risk                                               object
# VTE Risk                                                    object
# Height                                                      object
# Weight                                                      object
# Calculated BMI                                              object
# Actual BMI                                                  object
# BMI Flag                                                    object
# Emergency Admissions Upto 36 Months After PerformedTime      int64
# Has Comorbidity Recorded on Spell                           object
# Has Bleeding Event (or Stroke) on Spell                     object
# Has Stroke on Spell                                         object
# Has Thrombosis on Spell                                     object
# Treatment_days                                             float64
# dtype: object

# %% [markdown]
# ## 3- Convert Objects to Numeric values of selected columns

# %%
data["MRN"] = pd.to_numeric(data["MRN"])
data["PersonSK"] = pd.to_numeric(data["PersonSK"])
data["EncounterSK"] = pd.to_numeric(data["EncounterSK"])
data["Length Of Stay"] = pd.to_numeric(data["Length Of Stay"])
data["EventSk"] = pd.to_numeric(data["EventSk"])
data["Age at Given Date"] = pd.to_numeric(data["Age at Given Date"])
data["AC Amount"] = pd.to_numeric(data["AC Amount"])
#data["EGFR Result"] = pd.to_numeric(data["EGFR Result"])
data["Height"] = pd.to_numeric(data["Height"])
data["Weight"] = pd.to_numeric(data["Weight"])
data["Calculated BMI"] = pd.to_numeric(data["Calculated BMI"])
data["Actual BMI"] = pd.to_numeric(data["Actual BMI"])
#data["Difference in BMIs"] = pd.to_numeric(data["Difference in BMIs"])
data["Emergency Admissions Upto 36 Months After PerformedTime"] = pd.to_numeric(data["Emergency Admissions Upto 36 Months After PerformedTime"])
#data["Mat Admissions Within 3 Years"] = pd.to_numeric(data["Mat Admissions Within 3 Years"])

# %%
data.dtypes
#data.iloc[[24667]]
# Out:
# MRN                                                          int64
# Ethnic Group                                                object
# PersonSK                                                     int64
# EncounterSK                                                  int64
# Length Of Stay                                             float64
# EventSk                                                      int64
# Age at Given Date                                            int64
# EventType                                                   object
# AC Amount                                                  float64
# EGFR Result 60 Or Less                                      object
# EGFR Result                                                 object
# Gender                                                      object
# Date Of Death                                               object
# Deceased in EPR                                             object
# Clinical Display                                            object
# Bleeding Risk                                               object
# VTE Risk                                                    object
# Height                                                     float64
# Weight                                                     float64
# Calculated BMI                                             float64
# Actual BMI                                                 float64
# BMI Flag                                                    object
# Emergency Admissions Upto 36 Months After PerformedTime      int64
# Has Comorbidity Recorded on Spell                           object
# Has Bleeding Event (or Stroke) on Spell                     object
# Has Stroke on Spell                                         object
# Has Thrombosis on Spell                                     object
# Treatment_days                                             float64
# dtype: object

# %%
data.isnull( ).sum( )
# Out:
# MRN                                                            0
# Ethnic Group                                                   0
# PersonSK                                                       0
# EncounterSK                                                    0
# Length Of Stay                                               988
# EventSk                                                        0
# Age at Given Date                                              0
# EventType                                                      0
# AC Amount                                                      4
# EGFR Result 60 Or Less                                         0
# EGFR Result                                                 2613
# Gender                                                         0
# Date Of Death                                                  0
# Deceased in EPR                                                0
# Clinical Display                                               1
# Bleeding Risk                                               3919
# VTE Risk                                                    3867
# Height                                                     60258
# Weight                                                     52632
# Calculated BMI                                             68668
# Actual BMI                                                 74604
# BMI Flag                                                       0
# Emergency Admissions Upto 36 Months After PerformedTime        0
# Has Comorbidity Recorded on Spell                              0
# Has Bleeding Event (or Stroke) on Spell                        0
# Has Stroke on Spell                                            0
# Has Thrombosis on Spell                                        0
# Treatment_days                                             17544
# dtype: int64

# %%
data.nunique( )
# Out:
# MRN                                                         10619
# Ethnic Group                                                   17
# PersonSK                                                    10619
# EncounterSK                                                 18672
# Length Of Stay                                                126
# EventSk                                                    183552
# Age at Given Date                                              90
# EventType                                                       6
# AC Amount                                                      44
# EGFR Result 60 Or Less                                          2
# EGFR Result                                                   106
# Gender                                                          2
# Date Of Death                                                2409
# Deceased in EPR                                                 2
# Clinical Display                                            65849
# Bleeding Risk                                                   3
# VTE Risk                                                        3
# Height                                                        454
# Weight                                                       2356
# Calculated BMI                                              14774
# Actual BMI                                                   3077
# BMI Flag                                                        2
# Emergency Admissions Upto 36 Months After PerformedTime        35
# Has Comorbidity Recorded on Spell                               2
# Has Bleeding Event (or Stroke) on Spell                         2
# Has Stroke on Spell                                             2
# Has Thrombosis on Spell                                         2
# Treatment_days                                               1681
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183552 entries, 0 to 183551
# Data columns (total 28 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   MRN                                                      183552 non-null  int64
#  1   Ethnic Group                                             183552 non-null  object
#  2   PersonSK                                                 183552 non-null  int64
#  3   EncounterSK                                              183552 non-null  int64
#  4   Length Of Stay                                           182564 non-null  float64
#  5   EventSk                                                  183552 non-null  int64
#  6   Age at Given Date                                        183552 non-null  int64
#  7   EventType                                                183552 non-null  object
#  8   AC Amount                                                183548 non-null  float64
#  9   EGFR Result 60 Or Less                                   183552 non-null  object
#  10  EGFR Result                                              180939 non-null  object
#  11  Gender                                                   183552 non-null  object
#  12  Date Of Death                                            183552 non-null  object
#  13  Deceased in EPR                                          183552 non-null  object
#  14  Clinical Display                                         183551 non-null  object
#  15  Bleeding Risk                                            179633 non-null  object
#  16  VTE Risk                                                 179685 non-null  object
#  17  Height                                                   123294 non-null  float64
#  18  Weight                                                   130920 non-null  float64
#  19  Calculated BMI                                           114884 non-null  float64
#  20  Actual BMI                                               108948 non-null  float64
#  21  BMI Flag                                                 183552 non-null  object
#  22  Emergency Admissions Upto 36 Months After PerformedTime  183552 non-null  int64
#  23  Has Comorbidity Recorded on Spell                        183552 non-null  object
#  24  Has Bleeding Event (or Stroke) on Spell                  183552 non-null  object
#  25  Has Stroke on Spell                                      183552 non-null  object
#  26  Has Thrombosis on Spell                                  183552 non-null  object
#  27  Treatment_days                                           166008 non-null  float64
# dtypes: float64(7), int64(6), object(15)
# memory usage: 39.2+ MB

# %%
data.EventType.unique()
# Out:
# array(['rivaroxaban', 'apixaban', 'warfarin', 'edoxaban',
#        'dabigatran etexilate', 'dabigatran'], dtype=object)

# %% [markdown]
# ### Removing "Warfarin" drug aka event type from the data

# %%
data = data[data.EventType != "warfarin"]
data.shape
# Out:
# (166008, 28)

# %%
data1 = data

# %% [markdown]
# ### Replce EGFR Results >90 to 100

# %%
data["EGFR Result"].unique()
# Out:
# array([61, 79, '>90', 72, 42, 62, 53, 23, 32, 30, 37, 68, 75, 29, 27, 25,
#        35, 21, 16, 14, 59, 60, 57, 89, 83, 47, 46, 44, 40, 69, 81, 67, 52,
#        43, 41, 51, 55, 54, 74, 82, 70, 28, 31, 38, 64, 73, 71, 78, 49, 76,
#        65, 77, 63, 66, 84, 86, 58, 56, 87, 80, 48, 36, 34, 9, 11, 50, 33,
#        39, 22, 'Not applicable', nan, 88, 20, 24, 85,
#        'Probably contaminated with Potassium EDTA, suggest rpt.', 45,
#        'No sample received', 19, 26, 18, 12, 10, 15, 17, 13, 'Comment', 7,
#        8, 99, 'Not Available', '** INSUFFICIENT SPECIMEN **', 6, 5,
#        'Grossly haemolysed', 112, 117, 158, 121, 111, 137], dtype=object)

# %%
data1["EGFR Result"].replace({">90": 100}, inplace=True)
data1["EGFR Result"].replace({"Not applicable": 0}, inplace=True)
data1["EGFR Result"].replace({"Probably contaminated with Potassium EDTA, suggest rpt.": 0}, inplace=True)
data1["EGFR Result"].replace({"No sample received": 0}, inplace=True)
data1["EGFR Result"].replace({"Comment": 0}, inplace=True)
data1["EGFR Result"].replace({"Not Available": 0}, inplace=True)
data1["EGFR Result"].replace({"** INSUFFICIENT SPECIMEN **": 0}, inplace=True)
data1["EGFR Result"].replace({"Grossly haemolysed": 0}, inplace=True)
data1["EGFR Result"] = pd.to_numeric(data1["EGFR Result"])
print(data1["EGFR Result"])
# Out:
# 0         61.0
# 1         61.0
# 2         61.0
# 3         61.0
# 4         61.0
#           ...
# 183546    36.0
# 183547    36.0
# 183548    36.0
# 183549    36.0
# 183550    36.0
# Name: EGFR Result, Length: 166008, dtype: float64

# %% [markdown]
# #### Merge dabigatran and dabigatran etexilate from eventtype

# %%
data1.loc[data1['EventType']=="dabigatran etexilate", 'EventType'] = "dabigatran"

# %%
data1.EventType.unique()
# Out:
# array(['rivaroxaban', 'apixaban', 'edoxaban', 'dabigatran'], dtype=object)

# %%
data1.to_csv ("clean_DOAC2022.csv", index = False, header=True, encoding='utf-8')

# %% [markdown]
# # Clean DOAC2022 CSV File

# %%
df = pd.read_csv("clean_DOAC2022.csv")

# %%
df.head()
# Out:
#    MRN     Ethnic Group  PersonSK  EncounterSK  Length Of Stay    EventSk  \
# 0   96  white - british   5859512     39337940             9.0  832948603
# 1   96  white - british   5859512     39337940             9.0  834980349
# 2   96  white - british   5859512     39337940             9.0  837113509
# 3   96  white - british   5859512     39337940             9.0  838714390
# 4   96  white - british   5859512     39337940             9.0  840199866
#
#    Age at Given Date    EventType  AC Amount EGFR Result 60 Or Less  ...  \
# 0                 71  rivaroxaban       15.0                     no  ...
# 1                 71  rivaroxaban       15.0                     no  ...
# 2                 71  rivaroxaban       15.0                     no  ...
# 3                 71  rivaroxaban       15.0                     no  ...
# 4                 71  rivaroxaban       15.0                     no  ...
#
#    Weight Calculated BMI Actual BMI BMI Flag  \
# 0     NaN            NaN        NaN       no
# 1    51.5      20.629707      20.63       no
# 2    51.5      20.629707      20.63       no
# 3    51.5      20.629707      20.63       no
# 4    51.5      20.629707      20.63       no
#
#   Emergency Admissions Upto 36 Months After PerformedTime  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   Has Comorbidity Recorded on Spell Has Bleeding Event (or Stroke) on Spell  \
# 0                               yes                                      no
# 1                               yes                                      no
# 2                               yes                                      no
# 3                               yes                                      no
# 4                               yes                                      no
#
#    Has Stroke on Spell  Has Thrombosis on Spell  Treatment_days
# 0                   no                       no          1117.0
# 1                   no                       no          1116.0
# 2                   no                       no          1115.0
# 3                   no                       no          1114.0
# 4                   no                       no          1113.0
#
# [5 rows x 28 columns]

# %%
print("Shape of data: ", df.shape)
print(df.columns)
# Out:
# Shape of data:  (166008, 28)
# Index(['MRN', 'Ethnic Group', 'PersonSK', 'EncounterSK', 'Length Of Stay',
#        'EventSk', 'Age at Given Date', 'EventType', 'AC Amount',
#        'EGFR Result 60 Or Less', 'EGFR Result', 'Gender', 'Date Of Death',
#        'Deceased in EPR', 'Clinical Display', 'Bleeding Risk', 'VTE Risk',
#        'Height', 'Weight', 'Calculated BMI', 'Actual BMI', 'BMI Flag',
#        'Emergency Admissions Upto 36 Months After PerformedTime',
#        'Has Comorbidity Recorded on Spell',
#        'Has Bleeding Event (or Stroke) on Spell', 'Has Stroke on Spell',
#        'Has Thrombosis on Spell', 'Treatment_days'],
#       dtype='object')

# %%
df.isnull( ).sum( )
# Out:
# MRN                                                            0
# Ethnic Group                                                   0
# PersonSK                                                       0
# EncounterSK                                                    0
# Length Of Stay                                               971
# EventSk                                                        0
# Age at Given Date                                              0
# EventType                                                      0
# AC Amount                                                      4
# EGFR Result 60 Or Less                                         0
# EGFR Result                                                 2613
# Gender                                                         0
# Date Of Death                                                  0
# Deceased in EPR                                                0
# Clinical Display                                               1
# Bleeding Risk                                               3919
# VTE Risk                                                    3867
# Height                                                     54351
# Weight                                                     47908
# Calculated BMI                                             62037
# Actual BMI                                                 67282
# BMI Flag                                                       0
# Emergency Admissions Upto 36 Months After PerformedTime        0
# Has Comorbidity Recorded on Spell                              0
# Has Bleeding Event (or Stroke) on Spell                        0
# Has Stroke on Spell                                            0
# Has Thrombosis on Spell                                        0
# Treatment_days                                                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166008 entries, 0 to 166007
# Data columns (total 28 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   MRN                                                      166008 non-null  int64
#  1   Ethnic Group                                             166008 non-null  object
#  2   PersonSK                                                 166008 non-null  int64
#  3   EncounterSK                                              166008 non-null  int64
#  4   Length Of Stay                                           165037 non-null  float64
#  5   EventSk                                                  166008 non-null  int64
#  6   Age at Given Date                                        166008 non-null  int64
#  7   EventType                                                166008 non-null  object
#  8   AC Amount                                                166004 non-null  float64
#  9   EGFR Result 60 Or Less                                   166008 non-null  object
#  10  EGFR Result                                              163395 non-null  float64
#  11  Gender                                                   166008 non-null  object
#  12  Date Of Death                                            166008 non-null  object
#  13  Deceased in EPR                                          166008 non-null  object
#  14  Clinical Display                                         166007 non-null  object
#  15  Bleeding Risk                                            162089 non-null  object
#  16  VTE Risk                                                 162141 non-null  object
#  17  Height                                                   111657 non-null  float64
#  18  Weight                                                   118100 non-null  float64
#  19  Calculated BMI                                           103971 non-null  float64
#  20  Actual BMI                                               98726 non-null   float64
#  21  BMI Flag                                                 166008 non-null  object
#  22  Emergency Admissions Upto 36 Months After PerformedTime  166008 non-null  int64
#  23  Has Comorbidity Recorded on Spell                        166008 non-null  object
#  24  Has Bleeding Event (or Stroke) on Spell                  166008 non-null  object
#  25  Has Stroke on Spell                                      166008 non-null  object
#  26  Has Thrombosis on Spell                                  166008 non-null  object
#  27  Treatment_days                                           166008 non-null  float64
# dtypes: float64(8), int64(6), object(14)
# memory usage: 35.5+ MB

# %% [markdown]
# ### Length of Stay
# replace missing values with 0.

# %%
df["Length Of Stay"].unique()
# Out:
# array([  9.,   1.,  10.,   4.,   2.,   8.,   3.,  24.,   6.,  16.,  25.,
#          7.,   5.,  nan,  30.,  13.,  12.,  49.,  14.,   0.,  15.,  42.,
#         20.,  29.,  18.,  11.,  17.,  52.,  19.,  21.,  56.,  34.,  28.,
#         23.,  35.,  55.,  31.,  32.,  22.,  43.,  27.,  57.,  40.,  64.,
#         50.,  99.,  96.,  26.,  41., 148.,  45.,  38.,  44.,  59.,  36.,
#         58.,  51.,  94.,  37., 126.,  54.,  66.,  33.,  67.,  46.,  91.,
#         85.,  47.,  87.,  63., 117.,  62.,  82.,  39.,  61.,  72.,  92.,
#         65.,  69.,  48., 121.,  75., 101.,  53.,  81., 131.,  60.,  73.,
#        116., 102., 115.,  88., 155.,  83.,  80.,  68., 188., 111., 267.,
#         93.,  95.,  79.,  77., 110., 143.,  70., 114., 120., 133.,  86.,
#         78., 108.,  90.,  74.,  97., 107., 105., 112.,  84., 151., 142.,
#        123.,  89.,  76., 125.])

# %%
df["Length Of Stay"].fillna(0, inplace=True)

# %% [markdown]
# # Split the dataset into 4 sub datasets

# %%
obese_df = df[df['BMI Flag'] == 'yes']
not_obese_df = df[df['BMI Flag'] == 'no']
normal_kidney_df = df[df['EGFR Result 60 Or Less'] == 'no']
kidney_df = df[df['EGFR Result 60 Or Less'] == 'yes']

# %%
obese_df.to_csv ("obese_DOAC2022.csv", index = False, header=True, encoding='utf-8')
not_obese_df.to_csv ("non_obese_DOAC2022.csv", index = False, header=True, encoding='utf-8')
normal_kidney_df.to_csv ("normal_kidney_DOAC2022.csv", index = False, header=True, encoding='utf-8')
kidney_df.to_csv ("kidney_DOAC2022.csv", index = False, header=True, encoding='utf-8')

# %% [markdown]
# # 1. Obese Dataset

# %%
obese_df = pd.read_csv("obese_DOAC2022.csv")

# %%
print("Shape of data: ", obese_df.shape)
print(obese_df.columns)
# Out:
# Shape of data:  (29340, 28)
# Index(['MRN', 'Ethnic Group', 'PersonSK', 'EncounterSK', 'Length Of Stay',
#        'EventSk', 'Age at Given Date', 'EventType', 'AC Amount',
#        'EGFR Result 60 Or Less', 'EGFR Result', 'Gender', 'Date Of Death',
#        'Deceased in EPR', 'Clinical Display', 'Bleeding Risk', 'VTE Risk',
#        'Height', 'Weight', 'Calculated BMI', 'Actual BMI', 'BMI Flag',
#        'Emergency Admissions Upto 36 Months After PerformedTime',
#        'Has Comorbidity Recorded on Spell',
#        'Has Bleeding Event (or Stroke) on Spell', 'Has Stroke on Spell',
#        'Has Thrombosis on Spell', 'Treatment_days'],
#       dtype='object')

# %%
obese_df.isnull( ).sum( )
# Out:
# MRN                                                           0
# Ethnic Group                                                  0
# PersonSK                                                      0
# EncounterSK                                                   0
# Length Of Stay                                                0
# EventSk                                                       0
# Age at Given Date                                             0
# EventType                                                     0
# AC Amount                                                     1
# EGFR Result 60 Or Less                                        0
# EGFR Result                                                 479
# Gender                                                        0
# Date Of Death                                                 0
# Deceased in EPR                                               0
# Clinical Display                                              0
# Bleeding Risk                                               325
# VTE Risk                                                    321
# Height                                                       10
# Weight                                                        6
# Calculated BMI                                               10
# Actual BMI                                                 1875
# BMI Flag                                                      0
# Emergency Admissions Upto 36 Months After PerformedTime       0
# Has Comorbidity Recorded on Spell                             0
# Has Bleeding Event (or Stroke) on Spell                       0
# Has Stroke on Spell                                           0
# Has Thrombosis on Spell                                       0
# Treatment_days                                                0
# dtype: int64

# %%
obese_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29340 entries, 0 to 29339
# Data columns (total 28 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   MRN                                                      29340 non-null  int64
#  1   Ethnic Group                                             29340 non-null  object
#  2   PersonSK                                                 29340 non-null  int64
#  3   EncounterSK                                              29340 non-null  int64
#  4   Length Of Stay                                           29340 non-null  float64
#  5   EventSk                                                  29340 non-null  int64
#  6   Age at Given Date                                        29340 non-null  int64
#  7   EventType                                                29340 non-null  object
#  8   AC Amount                                                29339 non-null  float64
#  9   EGFR Result 60 Or Less                                   29340 non-null  object
#  10  EGFR Result                                              28861 non-null  float64
#  11  Gender                                                   29340 non-null  object
#  12  Date Of Death                                            29340 non-null  object
#  13  Deceased in EPR                                          29340 non-null  object
#  14  Clinical Display                                         29340 non-null  object
#  15  Bleeding Risk                                            29015 non-null  object
#  16  VTE Risk                                                 29019 non-null  object
#  17  Height                                                   29330 non-null  float64
#  18  Weight                                                   29334 non-null  float64
#  19  Calculated BMI                                           29330 non-null  float64
#  20  Actual BMI                                               27465 non-null  float64
#  21  BMI Flag                                                 29340 non-null  object
#  22  Emergency Admissions Upto 36 Months After PerformedTime  29340 non-null  int64
#  23  Has Comorbidity Recorded on Spell                        29340 non-null  object
#  24  Has Bleeding Event (or Stroke) on Spell                  29340 non-null  object
#  25  Has Stroke on Spell                                      29340 non-null  object
#  26  Has Thrombosis on Spell                                  29340 non-null  object
#  27  Treatment_days                                           29340 non-null  float64
# dtypes: float64(8), int64(6), object(14)
# memory usage: 6.3+ MB

# %% [markdown]
# # 1 - Missing Values

# %% [markdown]
# ## Handling missing values in EGFR Results

# %%
print(obese_df["EGFR Result"].value_counts())
# Out:
# 100.0    4855
# 55.0      549
# 59.0      529
# 57.0      481
# 74.0      467
#          ...
# 9.0         8
# 11.0        7
# 6.0         3
# 112.0       3
# 5.0         1
# Name: EGFR Result, Length: 86, dtype: int64

# %%
obese_df["EGFR Result"].describe()
# Out:
# count    28861.000000
# mean        62.930217
# std         24.146770
# min          0.000000
# 25%         44.000000
# 50%         62.000000
# 75%         82.000000
# max        112.000000
# Name: EGFR Result, dtype: float64

# %% [markdown]
# #### Since all the missing values in EGFR results hvae no in the corresponding "EGFR Result 60 Or Less" attribute.
# #### So, its better to replace the missing values with
# #### the average of only those records whoes corresponding EGFR values are greater than 60 or "no" in "EGFR result 60 or less".

# %%
temp_df = obese_df[["EGFR Result", "EGFR Result 60 Or Less"]]
print(temp_df.head())

tt = temp_df[temp_df['EGFR Result 60 Or Less'] == 'no']
print(tt.head())
print(tt.describe())
# Out:
#    EGFR Result EGFR Result 60 Or Less
# 0         54.0                    yes
# 1         54.0                    yes
# 2         54.0                    yes
# 3         54.0                    yes
# 4         54.0                    yes
#     EGFR Result EGFR Result 60 Or Less
# 8          74.0                     no
# 9          74.0                     no
# 10         74.0                     no
# 11         74.0                     no
# 12         74.0                     no
#         EGFR Result
# count  14981.000000
# mean      82.134504
# std       14.777342
# min        0.000000
# 25%       70.000000
# 50%       81.000000
# 75%      100.000000
# max      112.000000

# %% [markdown]
# replacing missing values in "EGFR Result" with mean.

# %%
EGFR_mean = 82.13
print(EGFR_mean)
# Out:
# 82.13

# %%
obese_df["EGFR Result"].fillna(EGFR_mean, inplace=True)

# %% [markdown]
# ## Handling missing values in Actual BMI
#
# Replacing missing values in Actual BMI from calculated BMI column

# %%
obese_df['Actual BMI'].fillna(obese_df['Calculated BMI'], inplace=True)

# %% [markdown]
# ## Handling missing values in Bleeding risk and VTE risk
# Drop the values where 'VTE Risk'and 'Bleeding Risk' are both null.

# %%
#obese_df = obese_df[obese_df['Bleeding Risk'].notna() && obese_df['VTE Risk'].notna()]
col_lst = ['Bleeding Risk', 'VTE Risk']
obese_df.dropna(axis = 0, subset = col_lst, how = 'all', inplace = True)

# %% [markdown]
# ## Handling missing values in AC Amount

# %%
obese_df = obese_df[obese_df['AC Amount'].notna()]

# %% [markdown]
# ## Handling missing values in Bleeding risk, Height, weight and calculated BMI.

# %%
obese_df = obese_df.dropna()

# %%
obese_df.isnull( ).sum( )
# Out:
# MRN                                                        0
# Ethnic Group                                               0
# PersonSK                                                   0
# EncounterSK                                                0
# Length Of Stay                                             0
# EventSk                                                    0
# Age at Given Date                                          0
# EventType                                                  0
# AC Amount                                                  0
# EGFR Result 60 Or Less                                     0
# EGFR Result                                                0
# Gender                                                     0
# Date Of Death                                              0
# Deceased in EPR                                            0
# Clinical Display                                           0
# Bleeding Risk                                              0
# VTE Risk                                                   0
# Height                                                     0
# Weight                                                     0
# Calculated BMI                                             0
# Actual BMI                                                 0
# BMI Flag                                                   0
# Emergency Admissions Upto 36 Months After PerformedTime    0
# Has Comorbidity Recorded on Spell                          0
# Has Bleeding Event (or Stroke) on Spell                    0
# Has Stroke on Spell                                        0
# Has Thrombosis on Spell                                    0
# Treatment_days                                             0
# dtype: int64

# %%
obese_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29004 entries, 0 to 29339
# Data columns (total 28 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   MRN                                                      29004 non-null  int64
#  1   Ethnic Group                                             29004 non-null  object
#  2   PersonSK                                                 29004 non-null  int64
#  3   EncounterSK                                              29004 non-null  int64
#  4   Length Of Stay                                           29004 non-null  float64
#  5   EventSk                                                  29004 non-null  int64
#  6   Age at Given Date                                        29004 non-null  int64
#  7   EventType                                                29004 non-null  object
#  8   AC Amount                                                29004 non-null  float64
#  9   EGFR Result 60 Or Less                                   29004 non-null  object
#  10  EGFR Result                                              29004 non-null  float64
#  11  Gender                                                   29004 non-null  object
#  12  Date Of Death                                            29004 non-null  object
#  13  Deceased in EPR                                          29004 non-null  object
#  14  Clinical Display                                         29004 non-null  object
#  15  Bleeding Risk                                            29004 non-null  object
#  16  VTE Risk                                                 29004 non-null  object
#  17  Height                                                   29004 non-null  float64
#  18  Weight                                                   29004 non-null  float64
#  19  Calculated BMI                                           29004 non-null  float64
#  20  Actual BMI                                               29004 non-null  float64
#  21  BMI Flag                                                 29004 non-null  object
#  22  Emergency Admissions Upto 36 Months After PerformedTime  29004 non-null  int64
#  23  Has Comorbidity Recorded on Spell                        29004 non-null  object
#  24  Has Bleeding Event (or Stroke) on Spell                  29004 non-null  object
#  25  Has Stroke on Spell                                      29004 non-null  object
#  26  Has Thrombosis on Spell                                  29004 non-null  object
#  27  Treatment_days                                           29004 non-null  float64
# dtypes: float64(8), int64(6), object(14)
# memory usage: 6.4+ MB

# %%
obese_df.nunique( )
# Out:
# MRN                                                         2417
# Ethnic Group                                                  15
# PersonSK                                                    2417
# EncounterSK                                                 3120
# Length Of Stay                                                88
# EventSk                                                    29004
# Age at Given Date                                             74
# EventType                                                      4
# AC Amount                                                     10
# EGFR Result 60 Or Less                                         2
# EGFR Result                                                   86
# Gender                                                         2
# Date Of Death                                                570
# Deceased in EPR                                                2
# Clinical Display                                           18505
# Bleeding Risk                                                  2
# VTE Risk                                                       2
# Height                                                       295
# Weight                                                      1408
# Calculated BMI                                              4512
# Actual BMI                                                  1859
# BMI Flag                                                       1
# Emergency Admissions Upto 36 Months After PerformedTime       28
# Has Comorbidity Recorded on Spell                              2
# Has Bleeding Event (or Stroke) on Spell                        2
# Has Stroke on Spell                                            2
# Has Thrombosis on Spell                                        2
# Treatment_days                                              1641
# dtype: int64

# %% [markdown]
# # 2 - Visualization

# %% [markdown]
# ## Ethinic Group

# %%
kk = obese_df["Ethnic Group"].value_counts()
print(kk)
plt.figure();

kk.plot(kind="pie");
# Out:
# white - british                       24316
# white - any other white background     2037
# other - not stated                      985
# asian or asian british - pakistani      615
# black or black british - caribbean      335
# white - irish                           317
# asian or asian british - indian         107
# other - not known                        87
# mixed - white and black caribbean        74
# other - any other ethnic group           62
# black - any other black background       37
# asian - any other asian background       17
# black or black british - african          8
# mixed - any other mixed background        4
# mixed - white and asian                   3
# Name: Ethnic Group, dtype: int64

# %% [markdown]
# ## Age at Given Date - bar

# %%
kk = obese_df['Age at Given Date'].value_counts()
#kk = pd.value_counts(obese_df['Age at Given Date'])
print(kk)
plt.figure(figsize=(18, 8), dpi=80);
plt.xlabel('Age at a given date')
plt.ylabel('count')
kk.plot(kind="bar");
# Out:
# 79    1424
# 83    1409
# 77    1359
# 78    1266
# 81    1266
#       ...
# 28       4
# 27       4
# 31       2
# 23       2
# 36       1
# Name: Age at Given Date, Length: 74, dtype: int64

# %% [markdown]
# ## EventType - pie

# %%
kk = obese_df["EventType"].value_counts()
print(kk)
plt.figure();

kk.plot(kind="pie");
# Out:
# apixaban       24085
# rivaroxaban     4522
# dabigatran       306
# edoxaban          91
# Name: EventType, dtype: int64

# %% [markdown]
# ## AC Amount -pie

# %%
kk = obese_df["AC Amount"].value_counts()
print(kk)
plt.figure(figsize=(10, 5), dpi=80);
plt.xlabel('AC Amount')
plt.ylabel('count')
kk.plot(kind="bar");
# Out:
# 5.0      13186
# 2.5      10209
# 20.0      2460
# 15.0      1851
# 10.0       901
# 110.0      212
# 150.0       92
# 30.0        48
# 60.0        43
# 75.0         2
# Name: AC Amount, dtype: int64

# %% [markdown]
# ## Bleeding Risk -pie

# %%
kk = obese_df["Bleeding Risk"].value_counts()
print(kk)
plt.figure();

kk.plot(kind="pie");
# Out:
# high    19862
# low      9142
# Name: Bleeding Risk, dtype: int64

# %% [markdown]
# ## VTE Risk  - pie

# %%
kk = obese_df["VTE Risk"].value_counts()
print(kk)
plt.figure();

kk.plot(kind="pie");
# Out:
# high    28769
# low       235
# Name: VTE Risk, dtype: int64

# %% [markdown]
# ## Emergency Admissions Upto 36 Months After PerformedTime - bar

# %%
kk = obese_df["Emergency Admissions Upto 36 Months After PerformedTime"].value_counts()
print(kk)
plt.figure(figsize=(10, 5), dpi=80);
plt.xlabel('Emergency Admissions Upto 36 Months After PerformedTime')
plt.ylabel('count')
kk.plot(kind="bar");
# Out:
# 1     7885
# 0     6434
# 2     4567
# 3     3642
# 4     2231
# 5     1276
# 6      732
# 7      612
# 8      347
# 10     317
# 9      212
# 11     181
# 12     170
# 14      74
# 15      61
# 19      52
# 13      50
# 23      43
# 17      28
# 22      19
# 21      17
# 18      16
# 24      11
# 16      10
# 26       7
# 20       6
# 31       2
# 29       2
# Name: Emergency Admissions Upto 36 Months After PerformedTime, dtype: int64

# %%
obese_df.to_csv ("obese.csv", index = False, header=True, encoding='utf-8')

# %% [markdown]
# # 2. Non-Obese Dataset

# %%
non_obese_df = pd.read_csv("non_obese_DOAC2022.csv")

# %%
print("Shape of data: ", non_obese_df.shape)
print(non_obese_df.columns)
# Out:
# Shape of data:  (136668, 28)
# Index(['MRN', 'Ethnic Group', 'PersonSK', 'EncounterSK', 'Length Of Stay',
#        'EventSk', 'Age at Given Date', 'EventType', 'AC Amount',
#        'EGFR Result 60 Or Less', 'EGFR Result', 'Gender', 'Date Of Death',
#        'Deceased in EPR', 'Clinical Display', 'Bleeding Risk', 'VTE Risk',
#        'Height', 'Weight', 'Calculated BMI', 'Actual BMI', 'BMI Flag',
#        'Emergency Admissions Upto 36 Months After PerformedTime',
#        'Has Comorbidity Recorded on Spell',
#        'Has Bleeding Event (or Stroke) on Spell', 'Has Stroke on Spell',
#        'Has Thrombosis on Spell', 'Treatment_days'],
#       dtype='object')

# %%
non_obese_df.isnull( ).sum( )
# Out:
# MRN                                                            0
# Ethnic Group                                                   0
# PersonSK                                                       0
# EncounterSK                                                    0
# Length Of Stay                                                 0
# EventSk                                                        0
# Age at Given Date                                              0
# EventType                                                      0
# AC Amount                                                      3
# EGFR Result 60 Or Less                                         0
# EGFR Result                                                 2134
# Gender                                                         0
# Date Of Death                                                  0
# Deceased in EPR                                                0
# Clinical Display                                               1
# Bleeding Risk                                               3594
# VTE Risk                                                    3546
# Height                                                     54341
# Weight                                                     47902
# Calculated BMI                                             62027
# Actual BMI                                                 65407
# BMI Flag                                                       0
# Emergency Admissions Upto 36 Months After PerformedTime        0
# Has Comorbidity Recorded on Spell                              0
# Has Bleeding Event (or Stroke) on Spell                        0
# Has Stroke on Spell                                            0
# Has Thrombosis on Spell                                        0
# Treatment_days                                                 0
# dtype: int64

# %%
non_obese_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136668 entries, 0 to 136667
# Data columns (total 28 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   MRN                                                      136668 non-null  int64
#  1   Ethnic Group                                             136668 non-null  object
#  2   PersonSK                                                 136668 non-null  int64
#  3   EncounterSK                                              136668 non-null  int64
#  4   Length Of Stay                                           136668 non-null  float64
#  5   EventSk                                                  136668 non-null  int64
#  6   Age at Given Date                                        136668 non-null  int64
#  7   EventType                                                136668 non-null  object
#  8   AC Amount                                                136665 non-null  float64
#  9   EGFR Result 60 Or Less                                   136668 non-null  object
#  10  EGFR Result                                              134534 non-null  float64
#  11  Gender                                                   136668 non-null  object
#  12  Date Of Death                                            136668 non-null  object
#  13  Deceased in EPR                                          136668 non-null  object
#  14  Clinical Display                                         136667 non-null  object
#  15  Bleeding Risk                                            133074 non-null  object
#  16  VTE Risk                                                 133122 non-null  object
#  17  Height                                                   82327 non-null   float64
#  18  Weight                                                   88766 non-null   float64
#  19  Calculated BMI                                           74641 non-null   float64
#  20  Actual BMI                                               71261 non-null   float64
#  21  BMI Flag                                                 136668 non-null  object
#  22  Emergency Admissions Upto 36 Months After PerformedTime  136668 non-null  int64
#  23  Has Comorbidity Recorded on Spell                        136668 non-null  object
#  24  Has Bleeding Event (or Stroke) on Spell                  136668 non-null  object
#  25  Has Stroke on Spell                                      136668 non-null  object
#  26  Has Thrombosis on Spell                                  136668 non-null  object
#  27  Treatment_days                                           136668 non-null  float64
# dtypes: float64(8), int64(6), object(14)
# memory usage: 29.2+ MB

# %% [markdown]
# ## 1. Missing values

# %%
print(non_obese_df["EGFR Result"].value_counts())
# Out:
# 100.0    33591
# 60.0      2025
# 56.0      2007
# 73.0      2005
# 57.0      1994
#          ...
# 7.0          3
# 99.0         2
# 137.0        2
# 5.0          1
# 111.0        1
# Name: EGFR Result, Length: 93, dtype: int64

# %%
non_obese_df = non_obese_df.dropna()

# %%
non_obese_df.shape
# Out:
# (69664, 28)

# %%
non_obese_df.to_csv ("non_obese.csv", index = False, header=True, encoding='utf-8')

# %% [markdown]
# ### convert nominal values to numerical
# Material Attribute is converted as
# abs = 0, pla = 1
# Infill Pattrens are converted into
# grid = 0, honeycomb = 1

# %%
data.material = [0 if each == "abs" else 1 for each in data.material]
data.infill_pattern = [0 if each == "grid" else 1 for each in data.infill_pattern]

# %% [markdown]
# ### convert numerical values to nominal ---> Numerical Binning
# data.elongation = ['small' if each >=0 and each <1  else 'Big' if  each >=1 and each <3   else 'very_Big' for each in data.elongation]
#
# 'small' = [0,1], 'big' =[1,3], 'very big' = [3,4]

# %%
data['elongation'] = pd.cut(data['elongation'], bins=[0,1,3,4], labels=["small", "big", "very_big"])

# %%
X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]

# %% [markdown]
# ### Count of each class in class-attribute

# %%
data['elongation'].value_counts()
# Out:
# big         34
# small       11
# very_big     5
# Name: elongation, dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Pair Plots

# %%
g = sns.pairplot(data, hue='EventType', markers='+')
g._legend.get_title().set_fontsize(20)
#plt.show()

# %%
g = sns.violinplot(y='elongation', x='layer_height', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='elongation', x='wall_thickness', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='elongation', x='infill_density', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='elongation', x='infill_pattern', data=data, inner='quartile')
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
corr_matrix = data.corr()
plt.figure(figsize=(12, 10)) ### Setting the size of the plot
sns.heatmap(data = corr_matrix,cmap='BrBG', annot=True, linewidths=0.2)

# %% [markdown]
# ## Data Normalization
# Normalization refers to rescaling real valued numeric attributes into the range 0 and 1.

# %%
normalized_X = preprocessing.normalize(X)
print(normalized_X[0:2])
# Out:
# [[8.04752412e-05 3.21900965e-02 3.62138585e-01 0.00000000e+00
#   8.85227653e-01 2.41425724e-01 1.60950482e-01 0.00000000e+00
#   0.00000000e+00]
#  [7.83110326e-05 2.74088614e-02 3.52399647e-01 3.91555163e-03
#   8.80999117e-01 2.54510856e-01 1.56622065e-01 0.00000000e+00
#   9.78887907e-02]]

# %% [markdown]
# ## Data Standardization
# Standardization refers to shifting the distribution of each attribute to have a mean of zero and a standard deviation of one (unit variance).

# %%
standardized_X = preprocessing.scale(X)
print(standardized_X[0:2])
# Out:
# [[-1.34902998  0.96081674  1.45766996 -1.         -0.10223973 -1.41421356
#   -0.81649658 -1.         -1.41421356]
#  [-1.34902998  0.61519921  1.45766996  1.          0.23855936 -0.70710678
#   -0.81649658 -1.         -0.70710678]]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Looking for any null/missing values in the data set

# %%
print(data.isnull().any())
# Out:
# layer_height          False
# wall_thickness        False
# infill_density        False
# infill_pattern        False
# nozzle_temperature    False
# bed_temperature       False
# print_speed           False
# material              False
# fan_speed             False
# roughness             False
# tension_strenght      False
# elongation            False
# dtype: bool

# %% [markdown]
# No need of Feature imputation as there is no missing values.

# %% [markdown]
# ## Outlier Detection

# %%
sns.boxplot(data=standardized_X, orient="v", palette="Set2")

# %% [markdown]
# # Classifiers

# %% [markdown]
# ## 1. Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics
from sklearn.tree import export_graphviz

# %%
X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]
#Normalised Data
normalized_X = preprocessing.normalize(X)
# Standardised Data
standardized_X = preprocessing.scale(X)
#encode categorical data into digits
y = pd.get_dummies(y)
print(y.head())
# Out:
#    elongation_small  elongation_big  elongation_very_big
# 0                 0               1                    0
# 1                 0               1                    0
# 2                 1               0                    0
# 3                 1               0                    0
# 4                 1               0                    0

# %%
########################################## Using Normal Data
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1)
# decision tree construction 
dt = DecisionTreeClassifier(criterion = 'entropy', random_state=1)
result_DT= dt.fit(X_train, y_train)
#pridiction
y_pred = dt.predict(X_test)
#accuracy
data_accuracy = metrics.accuracy_score(y_test, y_pred)
print("Data Accuracy:",data_accuracy)
########################################## Using Normalised Data
# train test split
X_train, X_test, y_train, y_test = train_test_split(normalized_X, y,test_size=0.3, random_state=1)
# decision tree construction 
dt = DecisionTreeClassifier(criterion = 'entropy', random_state=1)
result_DT= dt.fit(X_train, y_train)
#pridiction
y_pred = dt.predict(X_test)
#accuracy
data_accuracy = metrics.accuracy_score(y_test, y_pred)
print("Normalised data Accuracy:",data_accuracy)
########################################## Using Standardised Data
# train test split
X_train, X_test, y_train, y_test = train_test_split(standardized_X, y,test_size=0.3, random_state=1)
# decision tree construction 
dt = DecisionTreeClassifier(criterion = 'entropy', random_state=1)
result_DT= dt.fit(X_train, y_train)
#pridiction
y_pred = dt.predict(X_test)
#accuracy
data_accuracy = metrics.accuracy_score(y_test, y_pred)
print("Standardised Accuracy:",data_accuracy)
# Out:
# Data Accuracy: 0.8666666666666667
# Normalised data Accuracy: 0.8
# Standardised Accuracy: 0.8666666666666667

# %%
namez =  ['Small','Big','very_Big']
print(metrics.classification_report(y_test, y_pred, target_names=namez, digits=2,output_dict=False))
# Out:
#               precision    recall  f1-score   support
#
#        Small       0.67      0.67      0.67         3
#          Big       0.90      0.90      0.90        10
#     very_Big       1.00      1.00      1.00         2
#
#    micro avg       0.87      0.87      0.87        15
#    macro avg       0.86      0.86      0.86        15
# weighted avg       0.87      0.87      0.87        15
#  samples avg       0.87      0.87      0.87        15

# %%
#confusion matrix
print('Confusion Matrix')
species = np.array(y_test).argmax(axis=1)
predictions = np.array(y_pred).argmax(axis=1)
print(confusion_matrix(species, predictions))
# Out:
# Confusion Matrix
# [[2 1 0]
#  [1 9 0]
#  [0 0 2]]

# %%
# Variable importance in classifier
print("Variable importacne in the classifier.")
pd.concat((pd.DataFrame(data.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(result_DT.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]
# Out:
# Variable importacne in the classifier.
#               variable  importance
# 0       wall_thickness    0.438846
# 4      bed_temperature    0.437647
# 1       infill_density    0.123507
# 2       infill_pattern    0.000000
# 3   nozzle_temperature    0.000000
# 5          print_speed    0.000000
# 6             material    0.000000
# 7            fan_speed    0.000000
# 8            roughness    0.000000
# 9     tension_strenght         NaN
# 10          elongation         NaN

# %% [markdown]
# ### Tree Visualization

# %%
######## Creating Trees and printing on console. 
from sklearn import tree
import graphviz 
##### setting environment variable of Path for Graphviz
import os
os.environ["PATH"] += os.pathsep + 'C:/ProgramData/Anaconda3/Library/bin/graphviz/'

input_features = ['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']
output_features = 'elongation'
dot_data = tree.export_graphviz(result_DT, out_file=None, 
                      feature_names=input_features,  
                      class_names=output_features,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph 
######### Creating Tree and storing as PDF
#graph.render("DecisionTree")

# %% [markdown]
# #### Hyper Parameter Tuning

# %%
###############################################################################
###                Hyper parameter tuning and cross validation              ###
###############################################################################
from scipy.stats import randint
from sklearn.model_selection import GridSearchCV
import warnings
warnings.simplefilter("ignore")

##### 1 Setup the parameters
param_dist = {"max_depth":[1,9],
              "min_samples_leaf": [2,9],
              "criterion": ["gini","entropy"]}

#### 2 instantiate a decision tree
Dtree = DecisionTreeClassifier()

#### 3 instantiate ranommizedsearchCV object
tree_cv =  GridSearchCV(Dtree, param_dist, n_jobs=None, cv=10, verbose=0)

#### 4 fit to the data
Result = tree_cv.fit(X_train, y_train)
DT_result = Result
#### 5 print the tunned parameters and score
print("Best parameters are: {}".format(tree_cv.best_params_))
print("Best score is {} ".format(tree_cv.best_score_))
# Out:
# Best parameters are: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 2}
# Best score is 0.8857142857142857

# %% [markdown]
# ## 2. Bootstrap Aggregation(Bagging)

# %% [markdown]
# Bootstrap Aggregation (or Bagging for short), is a simple and very powerful ensemble method.
#
# An ensemble method is a technique that combines the predictions from multiple machine learning algorithms together to make more accurate predictions than any individual model.
#
# Bootstrap Aggregation is a general procedure that can be used to reduce the variance for those algorithm that have high variance. An algorithm that has high variance are decision trees, like classification and regression trees (CART).
#
# Decision trees are sensitive to the specific data on which they are trained. If the training data is changed (e.g. a tree is trained on a subset of the training data) the resulting decision tree can be quite different and in turn the predictions can be quite different.
#
# Bagging is the application of the Bootstrap procedure to a high-variance machine learning algorithm, typically decision trees.
#
# Let’s assume we have a sample dataset of 1000 instances (x) and we are using the CART algorithm. Bagging of the CART algorithm would work as follows.
#
# 1. Create many (e.g. 100) random sub-samples of our dataset with replacement.
# 2. Train a CART model on each sample.
# 3. Given a new dataset, calculate the average prediction from each model.
# For example, if we had 5 bagged decision trees that made the following class predictions for a in input sample: blue, blue, red, blue and red, we would take the most frequent class and predict blue.
#
#
# Source: https://machinelearningmastery.com/bagging-and-random-forest-ensemble-algorithms-for-machine-learning/

# %%
"""
Source: 
https://machinelearningmastery.com/hyperparameters-for-classification-machine-learning-algorithms/
"""
# example of grid searching key hyperparameters for BaggingClassifier

from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import RepeatedStratifiedKFold

X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]

# define models and parameters
model = BaggingClassifier(random_state=1)
n_estimators = [10, 100,200, 300, 1000]
# define grid search
grid = dict(n_estimators=n_estimators)
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X, y)

BA_result = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.893333 using {'n_estimators': 100}
# 0.873333 (0.090654) with: {'n_estimators': 10}
# 0.893333 (0.082282) with: {'n_estimators': 100}
# 0.873333 (0.107791) with: {'n_estimators': 200}
# 0.886667 (0.099852) with: {'n_estimators': 300}
# 0.886667 (0.105460) with: {'n_estimators': 1000}

# %% [markdown]
# ## 3. Random Forest

# %% [markdown]
# Random Forests are an improvement over bagged decision trees.
#
# A problem with decision trees like CART is that they are greedy. They choose which variable to split on using a greedy algorithm that minimizes error. As such, even with Bagging, the decision trees can have a lot of structural similarities and in turn have high correlation in their predictions.
#
# Combining predictions from multiple models in ensembles works better if the predictions from the sub-models are uncorrelated or at best weakly correlated.
#
# Random forest changes the algorithm for the way that the sub-trees are learned so that the resulting predictions from all of the subtrees have less correlation.

# %%
from sklearn.ensemble import RandomForestClassifier

#encode categorical data into digits
y = pd.get_dummies(y)
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1)
# Random Forests construction 
rf = RandomForestClassifier(criterion='entropy', 
                             n_estimators=1000,
                             min_samples_split=2,
                             min_samples_leaf=1,
                             max_features='auto',
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1,
                             verbose= 0)
result_RF = rf.fit(X_train, y_train)

#pridiction
y_pred = rf.predict(X_test)
#accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
namez =  ['Small','Big','very_Big']
print(metrics.classification_report(y_test, y_pred, target_names=namez, digits=2,output_dict=False)) 

#confusion matrix
species = np.array(y_test).argmax(axis=1)
predictions = np.array(y_pred).argmax(axis=1)
print("Confusion Matrix")
print(confusion_matrix(species, predictions))
# Out:
# Accuracy: 0.7333333333333333
#               precision    recall  f1-score   support
#
#        Small       1.00      0.33      0.50         3
#          Big       0.71      1.00      0.83        10
#     very_Big       0.00      0.00      0.00         2
#
#    micro avg       0.73      0.73      0.73        15
#    macro avg       0.57      0.44      0.44        15
# weighted avg       0.68      0.73      0.66        15
#  samples avg       0.73      0.73      0.73        15
#
# Confusion Matrix
# [[ 1  2  0]
#  [ 0 10  0]
#  [ 0  2  0]]

# %% [markdown]
# ### Parameter Importance in Classifier

# %%
# Variable importance in classifier
print("Variable importacne in the classifier.")
print(pd.concat((pd.DataFrame(data.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(result_RF.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False))
# Out:
# Variable importacne in the classifier.
#               variable  importance
# 4      bed_temperature    0.255342
# 0       wall_thickness    0.188633
# 8            roughness    0.109408
# 5          print_speed    0.105179
# 1       infill_density    0.089240
# 6             material    0.078441
# 7            fan_speed    0.074950
# 2       infill_pattern    0.073452
# 3   nozzle_temperature    0.025354
# 9     tension_strenght         NaN
# 10          elongation         NaN

# %% [markdown]
# ### Hyper-parameter Tuning

# %%
###############################################################################
###                Hyper parameter tuning and cross validation              ###
###############################################################################

y = pd.get_dummies(y)
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1)

##### 1 Setup the parameters
param_dist = {"max_depth":[None,9],
              "min_samples_leaf": [1,50],
              "max_features":['sqrt', 'log2'],
              "n_estimators":[10,1000],
              "criterion": ["gini","entropy"]
              }

#### 2 instantiate a decision tree
RF_tree = RandomForestClassifier()

#### 3 instantiate ranommizedsearchCV object
tree_cv =  GridSearchCV(RF_tree, param_dist, n_jobs=-1, cv=5)

#### 4 fit to the data
Result = tree_cv.fit(X_train, y_train)

#### 5 print the tunned parameters and score
print("Best parameters are: {}".format(tree_cv.best_params_))
print("Best score is {} ".format(tree_cv.best_score_))
RF_result = Result
# Out:
# Best parameters are: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'n_estimators': 10}
# Best score is 0.8285714285714286

# %% [markdown]
# ## 4. K-Nearest Neighbhours

# %% [markdown]
# K-Nearest Neighbors, or KNN for short, is one of the simplest machine learning algorithms and is used in a wide array of institutions. KNN is a non-parametric, lazy learning algorithm. When we say a technique is non-parametric, it means that it does not make any assumptions about the underlying data. In other words, it makes its selection based off of the proximity to other data points regardless of what feature the numerical values represent. Being a lazy learning algorithm implies that there is little to no training phase. Therefore, we can immediately classify new data points as they present themselves.
#
# Pros:
# No assumptions about data
# Simple algorithm — easy to understand
# Can be used for classification and regression
# Cons:
# High memory requirement — All of the training data must be present in memory in order to calculate the closest K neighbors
# Sensitive to irrelevant features
# Sensitive to the scale of the data since we’re computing the distance to the closest K points
#
# Source: https://towardsdatascience.com/k-nearest-neighbor-python-2fccc47d2a55

# %%
"""
Source: 
https://machinelearningmastery.com/hyperparameters-for-classification-machine-learning-algorithms/
"""

# example of grid searching key hyperparametres for KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier


X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]
# define models and parameters
model = KNeighborsClassifier()
n_neighbors = range(1, 21, 2)
weights = ['uniform', 'distance']
metric = ['euclidean', 'manhattan', 'minkowski']
# define grid search
grid = dict(n_neighbors=n_neighbors,weights=weights,metric=metric)
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0, verbose=0)
######################################## Using raw data
grid_result = grid_search.fit(X, y)
KNN_result = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
#for mean, stdev, param in zip(means, stds, params):
#    print("%f (%f) with: %r" % (mean, stdev, param))
    
########################################## Using Standardised Data
print("Using Standardised Data")
grid_result = grid_search.fit(standardized_X, y)
KNN_result_standard = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
#for mean, stdev, param in zip(means, stds, params):
 #   print("%f (%f) with: %r" % (mean, stdev, param))

########################################## Using Normalised Data
print("Using Normalised Data")
grid_result = grid_search.fit(normalized_X, y)
KNN_result_normal = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
#for mean, stdev, param in zip(means, stds, params):
 #   print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.720000 using {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'uniform'}
# Using Standardised Data
# Best: 0.826667 using {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# Using Normalised Data
# Best: 0.686667 using {'metric': 'manhattan', 'n_neighbors': 17, 'weights': 'uniform'}

# %% [markdown]
# # Linear Regression
# The following are a set of methods intended for regression in which the target value is expected to be a linear combination of the features. In mathematical notation, if 'y'is the predicted value.
#
# 'y'(w, x) = w0 + w1.x1 + w2.x2 + ... + wp.xp
#
# Across the module, we designate the vector w1.x1 + w2.x2 + ... + wp.xp as coef_ and
# w0 as intercept_.

# %% [markdown]
# When we talk about Regression, we often end up discussing Linear and Logistic Regression. But, that’s not the end. Do you know there are 7 types of Regressions?
#
# Linear and logistic regression is just the most loved members from the family of regressions.  Last week, I saw a recorded talk at NYC Data Science Academy from Owen Zhang, Chief Product Officer at DataRobot. He said, ‘if you are using regression without regularization, you have to be very special!’. I hope you get what a person of his stature referred to.
#
# I understood it very well and decided to explore regularization techniques in detail.
#
# In this article, I have explained the complex science behind ‘Ridge Regression‘ and ‘Lasso Regression‘ which are the most fundamental regularization techniques used in data science, sadly still not used by many.
# Source: https://www.analyticsvidhya.com/blog/2016/01/ridge-lasso-regression-python-complete-tutorial/

# %% [markdown]
# ## 5. Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
import numpy as np

data = pd.read_csv("data.csv", sep = ",")

data.material = [0 if each == "abs" else 1 for each in data.material]
data.infill_pattern = [0 if each == "grid" else 1 for each in data.infill_pattern]

X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]
X.head()
#y.head()
# Out:
#    layer_height  wall_thickness  infill_density  infill_pattern  \
# 0          0.02               8              90               0
# 1          0.02               7              90               1
# 2          0.02               1              80               0
# 3          0.02               4              70               1
# 4          0.02               6              90               0
#
#    nozzle_temperature  bed_temperature  print_speed  material  fan_speed
# 0                 220               60           40         0          0
# 1                 225               65           40         0         25
# 2                 230               70           40         0         50
# 3                 240               75           40         0         75
# 4                 250               80           40         0        100

# %%
lnr_reg = LinearRegression()
MSEs = cross_val_score(lnr_reg, X,y, scoring='neg_mean_squared_error', cv=50 )
print(MSEs)
print("Mean Squared Error", np.mean(MSEs))
# Out:
# [-3.65330188e-01 -4.76180990e-02 -5.45610111e-01 -4.96339160e-02
#  -1.23157327e-01 -4.09992816e-01 -1.77736228e-02 -8.60577119e-02
#  -3.02177312e-01 -9.70162259e-02 -5.88991675e-01 -3.47478975e-01
#  -5.73521110e-02 -3.19506915e-01 -1.20716796e+00 -1.42520484e-02
#  -1.03124576e-01 -3.01795812e-04 -8.47667463e-03 -6.40373153e-02
#  -1.11602013e-03 -1.33930818e-03 -2.03044350e-01 -2.81657519e-01
#  -3.89981483e-02 -8.71260183e-03 -3.61217032e-01 -1.89013571e-02
#  -1.00940258e+00 -2.83586226e-02 -2.66619757e-01 -9.62821807e-02
#  -3.81853468e-01 -4.22000678e-01 -2.89825206e-01 -9.36220335e-02
#  -3.34108573e-01 -1.96216907e-02 -5.97323478e-03 -1.58626955e+00
#  -6.55399792e-01 -1.59250091e-01 -1.64756206e-03 -3.52167913e-01
#  -1.40875925e-01 -1.60245383e-02 -5.62741348e-01 -2.61484972e-01
#  -4.29404582e-01 -3.56735491e-01]
# Mean Squared Error -0.2627942700075234

# %% [markdown]
# ## 6. Ridged Regression

# %%
from sklearn.linear_model import Ridge

ridge_reg = Ridge()
params = {'alpha': [1e-15,1e-10,1e-8,1e-5,1e-2,1e-1, 1,0.1,0.01,0.001,2,4,5]}
grid_result = GridSearchCV(cv=50, scoring='neg_mean_squared_error', estimator=ridge_reg, param_grid=params)
grid_result = grid_result.fit(X, y)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

Ridge_result = grid_result
# Out:
# Best: -0.262596 using {'alpha': 0.01}

# %% [markdown]
# ## 7. Lasso Regression

# %%
from sklearn.linear_model import Lasso

data.material = [0 if each == "abs" else 1 for each in data.material]
data.infill_pattern = [0 if each == "grid" else 1 for each in data.infill_pattern]


X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]
normalized_X = preprocessing.normalize(X)
standardized_X = preprocessing.scale(X)
lasso_reg = Lasso()
params = {'alpha': [1e-15,1e-10,1e-8,1e-5,1e-2,1e-1, 1,0.1,0.01,0.001,2,4,5]}
grid_resul = GridSearchCV(cv=50, scoring='neg_mean_squared_error', estimator=lasso_reg, param_grid=params)
########################################## Using raw data
grid_result =grid_result.fit(X, y)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
LASSO_result = grid_result
# Out:
# Best: -0.277257 using {'alpha': 0.001}

# %% [markdown]
# ## 8. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

data['elongation'] = pd.cut(data['elongation'], bins=[0,1,3,4], labels=["small", "big", "very_big"])
X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]

# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0, verbose=0)


grid_result = grid_search.fit(X, y)
LR_result = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
    
########################################## Using Standardised Data
print("Using Standardised Data")
grid_result = grid_search.fit(standardized_X, y)
LR_result_standard = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

########################################## Using Normalised Data
print("Using Normalised Data")
grid_result = grid_search.fit(normalized_X, y)
LR_result_normal = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.766667 using {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.760000 (0.166295) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.760000 (0.166295) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.760000 (0.166295) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.733333 (0.151762) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.733333 (0.151762) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.733333 (0.151762) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.720000 (0.150439) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.733333 (0.139557) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.733333 (0.139557) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.740000 (0.155237) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.733333 (0.147304) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.733333 (0.152856) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.766667 (0.139557) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.766667 (0.139557) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.720000 (0.153002) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# Using Standardised Data
# Best: 0.780000 using {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.740000 (0.172526) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.740000 (0.172526) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.753333 (0.176599) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.766667 (0.159960) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.766667 (0.159960) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.780000 (0.175336) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.740000 (0.153437) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.740000 (0.153437) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.780000 (0.153002) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.746667 (0.121877) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.746667 (0.121877) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.773333 (0.151249) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.680000 (0.067118) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.680000 (0.067118) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.773333 (0.125559) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# Using Normalised Data
# Best: 0.680000 using {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.660000 (0.132868) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.660000 (0.132868) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.660000 (0.132868) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.680000 (0.067118) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.680000 (0.067118) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.680000 (0.067118) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.680000 (0.067118) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.680000 (0.067118) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.680000 (0.067118) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.680000 (0.067118) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.680000 (0.067118) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.680000 (0.067118) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.680000 (0.067118) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.680000 (0.067118) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.680000 (0.067118) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %% [markdown]
# ## 9. Gradient Bossting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

data = pd.read_csv("data.csv", sep = ",")
data.material = [0 if each == "abs" else 1 for each in data.material]
data.infill_pattern = [0 if each == "grid" else 1 for each in data.infill_pattern]
data['elongation'] = pd.cut(data['elongation'], bins=[0,1,3,4], labels=["small", "big", "very_big"])

X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]

# define models and parameters
model = GradientBoostingClassifier()
n_estimators = [10, 100, 1000]
learning_rate = [0.001, 0.01, 0.1]
subsample = [0.5, 0.7, 1.0]
max_depth = [3, 7, 9]
# define grid search
grid = dict(learning_rate=learning_rate, n_estimators=n_estimators, subsample=subsample, max_depth=max_depth)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)


grid_result = grid_search.fit(X, y)
GBC_result = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.840000 using {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 10, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# 0.773333 (0.160515) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5}
# 0.826667 (0.162236) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.7}
# 0.840000 (0.162236) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 10, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 10, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 10, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 100, 'subsample': 1.0}
# 0.793333 (0.150881) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 0.5}
# 0.813333 (0.158705) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 0.7}
# 0.833333 (0.164413) with: {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 10, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 10, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 10, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 100, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 100, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 100, 'subsample': 1.0}
# 0.793333 (0.150881) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 0.5}
# 0.833333 (0.146168) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 0.7}
# 0.833333 (0.164413) with: {'learning_rate': 0.001, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'subsample': 1.0}
# 0.793333 (0.156307) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
# 0.813333 (0.158003) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.7}
# 0.840000 (0.162236) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# 0.793333 (0.158375) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5}
# 0.826667 (0.149401) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.7}
# 0.806667 (0.196323) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 10, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 10, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 10, 'subsample': 1.0}
# 0.753333 (0.181563) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.5}
# 0.813333 (0.145940) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.7}
# 0.833333 (0.164413) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'subsample': 1.0}
# 0.800000 (0.145023) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 0.5}
# 0.806667 (0.147153) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 0.7}
# 0.826667 (0.181318) with: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 1.0}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 10, 'subsample': 0.5}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 10, 'subsample': 0.7}
# 0.680000 (0.067118) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 10, 'subsample': 1.0}
# 0.760000 (0.165625) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 100, 'subsample': 0.5}
# 0.833333 (0.146168) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 100, 'subsample': 0.7}
# 0.826667 (0.162578) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 100, 'subsample': 1.0}
# 0.800000 (0.162666) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 0.5}
# 0.820000 (0.159752) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 0.7}
# 0.826667 (0.181318) with: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 1.0}
# 0.766667 (0.154971) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.5}
# 0.766667 (0.197565) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.7}
# 0.826667 (0.158775) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 10, 'subsample': 1.0}
# 0.800000 (0.147627) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
# 0.813333 (0.175653) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.7}
# 0.806667 (0.191162) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# 0.773333 (0.148281) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.5}
# 0.813333 (0.183692) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.7}
# 0.806667 (0.196323) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 1.0}
# 0.773333 (0.162187) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 10, 'subsample': 0.5}
# 0.800000 (0.171038) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 10, 'subsample': 0.7}
# 0.840000 (0.160861) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 10, 'subsample': 1.0}
# 0.806667 (0.146721) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.5}
# 0.820000 (0.147077) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.7}
# 0.820000 (0.185797) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 1.0}
# 0.786667 (0.151175) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 0.5}
# 0.826667 (0.161894) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 0.7}
# 0.820000 (0.185797) with: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 1.0}
# 0.753333 (0.162510) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 10, 'subsample': 0.5}
# 0.813333 (0.146320) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 10, 'subsample': 0.7}
# 0.820000 (0.158705) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 10, 'subsample': 1.0}
# 0.806667 (0.146016) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 100, 'subsample': 0.5}
# 0.813333 (0.166848) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 100, 'subsample': 0.7}
# 0.826667 (0.181318) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 100, 'subsample': 1.0}
# 0.793333 (0.178850) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 0.5}
# 0.793333 (0.165625) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 0.7}
# 0.826667 (0.181318) with: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 1.0}

# %% [markdown]
# ## 10. Support Vector Machine

# %%
from sklearn.svm import SVC

data = pd.read_csv("data.csv", sep = ",")
data.material = [0 if each == "abs" else 1 for each in data.material]
data.infill_pattern = [0 if each == "grid" else 1 for each in data.infill_pattern]
data['elongation'] = pd.cut(data['elongation'], bins=[0,1,3,4], labels=["small", "big", "very_big"])

X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
y = data[['elongation']]

# define model and parameters
model = SVC()
kernel = ['poly', 'rbf', 'sigmoid']
C = [50, 10, 1.0, 0.1, 0.01]
gamma = ['scale']
# define grid search
grid = dict(kernel=kernel,C=C,gamma=gamma)
cv = RepeatedStratifiedKFold(n_splits=20, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0, verbose=1)

grid_result = grid_search.fit(X, y)
SVM_result = grid_result
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

########################################## Using Standardised Data
print("Using Standardised Data")
grid_result = grid_search.fit(standardized_X, y)
SVM_result_standard = grid_result
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
########################################## Using Normalised Data
print("Using Normalised Data")
grid_result = grid_search.fit(normalized_X, y)
SVM_result_normal = grid_result
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Fitting 60 folds for each of 15 candidates, totalling 900 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 900 out of 900 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Best: 0.753333 using {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.726667 (0.270308) with: {'C': 50, 'gamma': 'scale', 'kernel': 'poly'}
# 0.753333 (0.238607) with: {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.640000 (0.209125) with: {'C': 50, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.746667 (0.245493) with: {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 0.726667 (0.243265) with: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.680000 (0.175879) with: {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.720000 (0.245945) with: {'C': 1.0, 'gamma': 'scale', 'kernel': 'poly'}
# 0.680000 (0.175879) with: {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.680000 (0.175879) with: {'C': 1.0, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.680000 (0.175879) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}
# 0.680000 (0.175879) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.680000 (0.175879) with: {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 0.680000 (0.175879) with: {'C': 0.01, 'gamma': 'scale', 'kernel': 'poly'}
# 0.680000 (0.175879) with: {'C': 0.01, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.680000 (0.175879) with: {'C': 0.01, 'gamma': 'scale', 'kernel': 'sigmoid'}
# Using Standardised Data
# Fitting 60 folds for each of 15 candidates, totalling 900 fits
# [Parallel(n_jobs=-1)]: Done 900 out of 900 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Best: 0.806667 using {'C': 50, 'gamma': 'scale', 'kernel': 'poly'}
# Using Normalised Data
# Fitting 60 folds for each of 15 candidates, totalling 900 fits
# Best: 0.693333 using {'C': 50, 'gamma': 'scale', 'kernel': 'poly'}
# [Parallel(n_jobs=-1)]: Done 900 out of 900 | elapsed:    0.3s finished

# %% [markdown]
# # Result Comparisons

# %%
# Compare Algorithms
import pandas
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# load dataset
# Reading data from csv file
data = pd.read_csv("data.csv", sep = ",")
# Looking for any null/missing values in the data set
print("Looking for any null/missing values in the data set")
print(data.isnull().any())
#convert nominal values to numerical
data.material = [0 if each == "abs" else 1 for each in data.material]                  # abs = 0, pla = 1
data.infill_pattern = [0 if each == "grid" else 1 for each in data.infill_pattern]     # grid = 0, honeycomb = 1
#convert numerical values to nominal ---> Numerical Binning
data['elongation'] = pd.cut(data['elongation'], bins=[0,1,3,4], labels=["small", "big", "very_big"])

X = data[['layer_height', 'wall_thickness', 'infill_density', 'infill_pattern','nozzle_temperature', 'bed_temperature', 'print_speed', 'material','fan_speed']]
Y = data[['elongation']]

# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)

'''    
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
'''
# Out:
# Looking for any null/missing values in the data set
# layer_height          False
# wall_thickness        False
# infill_density        False
# infill_pattern        False
# nozzle_temperature    False
# bed_temperature       False
# print_speed           False
# material              False
# fan_speed             False
# roughness             False
# tension_strenght      False
# elongation            False
# dtype: bool
# LR: 0.680000 (0.271293)
# LDA: 0.760000 (0.215407)
# KNN: 0.580000 (0.260000)
# CART: 0.740000 (0.283549)
# NB: 0.740000 (0.283549)
# SVM: 0.680000 (0.240000)
# "    \n# boxplot algorithm comparison\nfig = plt.figure()\nfig.suptitle('Algorithm Comparison')\nax = fig.add_subplot(111)\nplt.boxplot(results)\nax.set_xticklabels(names)\nplt.show()\n"
