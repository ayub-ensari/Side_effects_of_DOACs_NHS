# %% [markdown]
# ### Importing Libraries

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn
from sklearn import preprocessing

# %% [markdown]
# ### Displaying the version of Libraries used

# %%
# Python version
print('Python: {}'.format(sys.version))
# pandas
print('pandas: {}'.format(pd.__version__))
# numpy
print('numpy: {}'.format(np.__version__))
# seaborn
print('seaborn: {}'.format(sns.__version__))
# scikit-learn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.9.5 (tags/v3.9.5:0a7dcbd, May  3 2021, 17:27:52) [MSC v.1928 64 bit (AMD64)]
# pandas: 1.4.1
# numpy: 1.22.2
# seaborn: 0.11.2
# sklearn: 1.0.2

# %% [markdown]
# # 1. Morbidly Obese Dataset

# %%
obese_df = pd.read_csv('Morbidly_Obese_Dataset.csv', header=0)

# %%
obese_df.shape
# Out:
# (4275, 25)

# %%
obese_df.head()
# Out:
#    Ethnicity  Age  Gender  LOS  CKD_Status  Bleeding_Risk  VTE_Risk  \
# 0          2   45       1    5           0              1         1
# 1          2   45       1    5           0              1         1
# 2          2   45       1    5           0              1         1
# 3          1   82       1    3           1              1         1
# 4          1   82       1    3           1              1         1
#
#    Comorbidity  Treatment_days  Apixa_10mg  ...  Edoxa_30mg  Edoxa_60mg  \
# 0            1            1314           0  ...           0           0
# 1            1            1313           0  ...           0           0
# 2            1            1312           0  ...           0           0
# 3            1             613           0  ...           0           0
# 4            1             612           0  ...           0           0
#
#    Riva_10mg  Riva_15mg  Riva_20mg  Mortality  Stroke  Emergency_visits  \
# 0          0          0          1          0       0                23
# 1          0          0          1          0       0                23
# 2          0          0          1          0       0                23
# 3          0          0          0          1       0                20
# 4          0          0          0          1       0                20
#
#    Bleeding  Thrombosis
# 0         2           0
# 1         2           0
# 2         2           0
# 3         2           0
# 4         2           0
#
# [5 rows x 25 columns]

# %%
obese_df.describe()
# Out:
#          Ethnicity          Age       Gender          LOS   CKD_Status  \
# count  4275.000000  4275.000000  4275.000000  4275.000000  4275.000000
# mean      1.129591    69.252865     0.431111    20.399532     0.491930
# std       0.451226    11.792442     0.495290    17.290599     0.499993
# min       1.000000    20.000000     0.000000     0.000000     0.000000
# 25%       1.000000    61.000000     0.000000     6.000000     0.000000
# 50%       1.000000    71.000000     0.000000    16.000000     0.000000
# 75%       1.000000    78.000000     1.000000    28.000000     1.000000
# max       3.000000    92.000000     1.000000    81.000000     1.000000
#
#        Bleeding_Risk     VTE_Risk  Comorbidity  Treatment_days   Apixa_10mg  \
# count    4275.000000  4275.000000  4275.000000     4275.000000  4275.000000
# mean        0.677895     0.987135     0.801170      508.510409     0.021520
# std         0.467338     0.112707     0.399167      460.671312     0.145128
# min         0.000000     0.000000     0.000000        0.000000     0.000000
# 25%         0.000000     1.000000     1.000000       87.000000     0.000000
# 50%         1.000000     1.000000     1.000000      410.000000     0.000000
# 75%         1.000000     1.000000     1.000000      855.000000     0.000000
# max         1.000000     1.000000     1.000000     1634.000000     1.000000
#
#        ...   Edoxa_30mg   Edoxa_60mg    Riva_10mg    Riva_15mg    Riva_20mg  \
# count  ...  4275.000000  4275.000000  4275.000000  4275.000000  4275.000000
# mean   ...     0.001404     0.000234     0.004211     0.059883     0.090292
# std    ...     0.037442     0.015294     0.064759     0.237298     0.286634
# min    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 50%    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 75%    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# max    ...     1.000000     1.000000     1.000000     1.000000     1.000000
#
#          Mortality       Stroke  Emergency_visits  Bleeding   Thrombosis
# count  4275.000000  4275.000000       4275.000000    4275.0  4275.000000
# mean      0.385497     0.060585          2.516257       2.0     0.021520
# std       0.486769     0.238595          2.912128       0.0     0.145128
# min       0.000000     0.000000          0.000000       2.0     0.000000
# 25%       0.000000     0.000000          1.000000       2.0     0.000000
# 50%       0.000000     0.000000          2.000000       2.0     0.000000
# 75%       1.000000     0.000000          3.000000       2.0     0.000000
# max       1.000000     1.000000         23.000000       2.0     1.000000
#
# [8 rows x 25 columns]

# %%
obese_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4275 entries, 0 to 4274
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ethnicity         4275 non-null   int64
#  1   Age               4275 non-null   int64
#  2   Gender            4275 non-null   int64
#  3   LOS               4275 non-null   int64
#  4   CKD_Status        4275 non-null   int64
#  5   Bleeding_Risk     4275 non-null   int64
#  6   VTE_Risk          4275 non-null   int64
#  7   Comorbidity       4275 non-null   int64
#  8   Treatment_days    4275 non-null   int64
#  9   Apixa_10mg        4275 non-null   int64
#  10  Apixa_2.5mg       4275 non-null   int64
#  11  Apixa_5mg         4275 non-null   int64
#  12  Dabi_110mg        4275 non-null   int64
#  13  Dabi_150mg        4275 non-null   int64
#  14  Dabi_75mg         4275 non-null   int64
#  15  Edoxa_30mg        4275 non-null   int64
#  16  Edoxa_60mg        4275 non-null   int64
#  17  Riva_10mg         4275 non-null   int64
#  18  Riva_15mg         4275 non-null   int64
#  19  Riva_20mg         4275 non-null   int64
#  20  Mortality         4275 non-null   int64
#  21  Stroke            4275 non-null   int64
#  22  Emergency_visits  4275 non-null   int64
#  23  Bleeding          4275 non-null   int64
#  24  Thrombosis        4275 non-null   int64
# dtypes: int64(25)
# memory usage: 835.1 KB

# %%
obese_df.columns
# Out:
# Index(['Ethnicity', 'Age', 'Gender', 'LOS', 'CKD_Status', 'Bleeding_Risk',
#        'VTE_Risk', 'Comorbidity', 'Treatment_days', 'Apixa_10mg',
#        'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg', 'Dabi_75mg',
#        'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
#        'Mortality', 'Stroke', 'Emergency_visits', 'Bleeding', 'Thrombosis'],
#       dtype='object')

# %%
obese_df['Mortality'] = obese_df.Mortality.astype('category')
obese_df['Stroke'] = obese_df.Stroke.astype('category')
obese_df['Bleeding'] = obese_df.Bleeding.astype('category')
obese_df['Thrombosis'] = obese_df.Thrombosis.astype('category')

# %% [markdown]
# # Predict Stroke among Patients receiving DOACs

# %% [markdown]
# ## 1. Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics
from sklearn.tree import export_graphviz
from sklearn import tree
from pydotplus import graph_from_dot_data
import graphviz

# %%
X = obese_df[['Ethnicity', 'Age', 'Gender', 'LOS', 'CKD_Status', 'Bleeding_Risk',
       'VTE_Risk', 'Comorbidity', 'Treatment_days', 'Apixa_10mg',
       'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg', 'Dabi_75mg',
       'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
       'Mortality', 'Emergency_visits', 'Bleeding', 'Thrombosis']]
y = obese_df[['Stroke']]
normalized_X = preprocessing.normalize(X)
#print(normalized_X[0:2])
standardized_X = preprocessing.scale(X)
#print(standardized_X[0:2])

########################################## Using raw Data
# train test split using stratification
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1,stratify=y)
# decision tree construction 
dt = DecisionTreeClassifier(criterion = 'entropy', random_state=1)
result_DT= dt.fit(X_train, y_train)
#pridiction
y_pred = dt.predict(X_test)
#accuracy
data_accuracy = metrics.accuracy_score(y_test, y_pred)
print("Data Accuracy: ",data_accuracy)
########################################## Using Normalised Data
# train test split using stratification
X_train, X_test, y_train, y_test = train_test_split(normalized_X, y,test_size=0.3, random_state=1,stratify=y)
# decision tree construction 
dt = DecisionTreeClassifier(criterion = 'entropy', random_state=1)
result_DT= dt.fit(X_train, y_train)
#pridiction
y_pred = dt.predict(X_test)
#accuracy
data_accuracy = metrics.accuracy_score(y_test, y_pred)
print("Normalised data Accuracy: ",data_accuracy)
########################################## Using Standardised Data
# train test split using stratification
X_train, X_test, y_train, y_test = train_test_split(standardized_X, y,test_size=0.3, random_state=1,stratify=y)
# decision tree construction 
dt = DecisionTreeClassifier(criterion = 'entropy', random_state=1)
result_DT= dt.fit(X_train, y_train)
#pridiction
y_pred = dt.predict(X_test)
#accuracy
data_accuracy = metrics.accuracy_score(y_test, y_pred)
print("Standardised Accuracy: ",data_accuracy)
# Out:
# Data Accuracy:  1.0
# Normalised data Accuracy:  0.995323460639127
# Standardised Accuracy:  1.0

# %%
X = obese_df[['Ethnicity', 'Age', 'Gender', 'LOS', 'CKD_Status', 'Bleeding_Risk',
       'VTE_Risk', 'Comorbidity', 'Treatment_days', 'Apixa_10mg',
       'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg', 'Dabi_75mg',
       'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
       'Mortality', 'Emergency_visits', 'Bleeding', 'Thrombosis']]
y = obese_df[['Stroke']]
normalized_X = preprocessing.normalize(X)
#print(normalized_X[0:2])
standardized_X = preprocessing.scale(X)
#print(standardized_X[0:2])

########################################## Using raw Data
# train test split using stratification
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1,stratify=y)
# decision tree construction 
dt = DecisionTreeClassifier(criterion = 'entropy', random_state=1)
result_DT= dt.fit(X_train, y_train)
#pridiction
y_pred = dt.predict(X_test)
#accuracy
data_accuracy = metrics.accuracy_score(y_test, y_pred)
print("Data Accuracy: ",data_accuracy)
###################################### Tree visualization
#features = ['Ethnicity', 'Age', 'Gender', 'LOS', 'Bleeding_Risk', 'VTE_Risk',
#       'CKD_Status', 'Obesity_status', 'Comorbidity', 'Treatment_days',
#       'Apixa_10mg', 'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg',
#       'Dabi_75mg', 'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg',
#       'Riva_20mg']
#cn=['0', '1']
## Setting figure size
#fig = plt.figure(figsize=(25,20))##

#tree.plot_tree(dt,
#           feature_names = features, 
#           class_names=cn,
#           filled = True);

# You can save your plot if you want
#fig.savefig('MyTree.png')
# Out:
# Data Accuracy:  1.0

# %%
print("Classification report:\n")
namez =  ["Stroke=0", "Stroke=1"]
print(metrics.classification_report(y_test, y_pred, target_names=namez, digits=2,output_dict=False)) 
#confusion matrix
print('\n \n \n Confusion Matrix')
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification report:
#
#               precision    recall  f1-score   support
#
#     Stroke=0       1.00      1.00      1.00      1205
#     Stroke=1       1.00      1.00      1.00        78
#
#     accuracy                           1.00      1283
#    macro avg       1.00      1.00      1.00      1283
# weighted avg       1.00      1.00      1.00      1283
#
#
#
#
#  Confusion Matrix
# [[1205    0]
#  [   0   78]]

# %%
# let's create a dictionary of features and their importance values
#feat_dict= {}
#for col, val in zip(X_train.columns, result_DT.feature_importances_):#sorted(zip(X_train.columns, result_DT.feature_importances_),key=lambda x:x[1],reverse=True):
#  feat_dict[col]=val
#feat_df = pd.DataFrame({'Feature':feat_dict.keys(),'Importance':feat_dict.values()})
#print(feat_df)
#print("\n\n\n\n\n sorted")
#print(feat_df.sort_values(by=['Importance'],ascending=False))

# %% [markdown]
# ## Variable importance - Decision Trees - Morbidly Obese Patients

# %%
# Variable importance in classifier
print("Variable importacne in the classifier.")
pd.concat((pd.DataFrame(X_train.columns, columns = ['variable']), 
           pd.DataFrame(result_DT.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)
# Out:
# Variable importacne in the classifier.
#             variable  importance
# 3                LOS    0.489033
# 1                Age    0.159227
# 8     Treatment_days    0.139378
# 23        Thrombosis    0.133668
# 11         Apixa_5mg    0.026225
# 4         CKD_Status    0.017450
# 0          Ethnicity    0.011760
# 5      Bleeding_Risk    0.010238
# 18         Riva_15mg    0.008114
# 19         Riva_20mg    0.004905
# 7        Comorbidity    0.000000
# 16        Edoxa_60mg    0.000000
# 22          Bleeding    0.000000
# 21  Emergency_visits    0.000000
# 20         Mortality    0.000000
# 17         Riva_10mg    0.000000
# 15        Edoxa_30mg    0.000000
# 6           VTE_Risk    0.000000
# 14         Dabi_75mg    0.000000
# 13        Dabi_150mg    0.000000
# 2             Gender    0.000000
# 10       Apixa_2.5mg    0.000000
# 9         Apixa_10mg    0.000000
# 12        Dabi_110mg    0.000000

# %% [markdown]
# ## 2. Random Forest

# %% [markdown]
# Random Forests are an improvement over bagged decision trees.
#
# A problem with decision trees like CART is that they are greedy. They choose which variable to split on using a greedy algorithm that minimizes error. As such, even with Bagging, the decision trees can have a lot of structural similarities and in turn have high correlation in their predictions.
#
# Combining predictions from multiple models in ensembles works better if the predictions from the sub-models are uncorrelated or at best weakly correlated.
#
# Random forest changes the algorithm for the way that the sub-trees are learned so that the resulting predictions from all of the subtrees have less correlation.

# %%
from sklearn.ensemble import RandomForestClassifier

X = obese_df[['Ethnicity', 'Age', 'Gender', 'LOS', 'CKD_Status', 'Bleeding_Risk',
       'VTE_Risk', 'Comorbidity', 'Treatment_days', 'Apixa_10mg',
       'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg', 'Dabi_75mg',
       'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
       'Mortality', 'Emergency_visits', 'Bleeding', 'Thrombosis']]
y = obese_df[['Stroke']]
normalized_X = preprocessing.normalize(X)
#print(normalized_X[0:2])
standardized_X = preprocessing.scale(X)
#print(standardized_X[0:2])

# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1,stratify=y)
# Random Forests construction 
rf = RandomForestClassifier(criterion='entropy', 
                             n_estimators=1000,
                             min_samples_split=2,
                             min_samples_leaf=1,
                             max_features='auto',
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1,
                             verbose= 0)

### fit/train model
result_RF = rf.fit(X_train, y_train.values.ravel())

#pridiction
y_pred = rf.predict(X_test)
#accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
namez =  ["Stroke=0", "Stroke=1"]
print(metrics.classification_report(y_test, y_pred, target_names=namez, digits=2,output_dict=False)) 

#confusion matrix
#species = np.array(y_test).argmax(axis=1)
#predictions = np.array(y_pred).argmax(axis=1)
print("Confusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#     Stroke=0       1.00      1.00      1.00      1205
#     Stroke=1       1.00      1.00      1.00        78
#
#     accuracy                           1.00      1283
#    macro avg       1.00      1.00      1.00      1283
# weighted avg       1.00      1.00      1.00      1283
#
# Confusion Matrix
# [[1205    0]
#  [   0   78]]

# %% [markdown]
# ## Variable importance - Random Forest - Morbidly Obese Patients

# %%
# Variable importance in classifier
print("Variable importacne in the classifier.")
pd.concat((pd.DataFrame(X_train.columns, columns = ['variable']), 
           pd.DataFrame(result_RF.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)
# Out:
# Variable importacne in the classifier.
#             variable  importance
# 3                LOS    0.305933
# 8     Treatment_days    0.158857
# 1                Age    0.142559
# 23        Thrombosis    0.088556
# 21  Emergency_visits    0.074545
# 5      Bleeding_Risk    0.058638
# 2             Gender    0.033155
# 11         Apixa_5mg    0.028428
# 20         Mortality    0.028296
# 4         CKD_Status    0.017037
# 7        Comorbidity    0.016927
# 10       Apixa_2.5mg    0.016403
# 0          Ethnicity    0.012807
# 18         Riva_15mg    0.007388
# 19         Riva_20mg    0.006348
# 9         Apixa_10mg    0.003427
# 6           VTE_Risk    0.000257
# 15        Edoxa_30mg    0.000243
# 17         Riva_10mg    0.000175
# 12        Dabi_110mg    0.000022
# 13        Dabi_150mg    0.000000
# 14         Dabi_75mg    0.000000
# 16        Edoxa_60mg    0.000000
# 22          Bleeding    0.000000

# %% [markdown]
# ## 3. K-Nearest Neighbhours

# %% [markdown]
# K-Nearest Neighbors, or KNN for short, is one of the simplest machine learning algorithms and is used in a wide array of institutions. KNN is a non-parametric, lazy learning algorithm. When we say a technique is non-parametric, it means that it does not make any assumptions about the underlying data. In other words, it makes its selection based off of the proximity to other data points regardless of what feature the numerical values represent. Being a lazy learning algorithm implies that there is little to no training phase. Therefore, we can immediately classify new data points as they present themselves.
#
# Pros:
# No assumptions about data
# Simple algorithm — easy to understand
# Can be used for classification and regression
# Cons:
# High memory requirement — All of the training data must be present in memory in order to calculate the closest K neighbors
# Sensitive to irrelevant features
# Sensitive to the scale of the data since we’re computing the distance to the closest K points
#
# Source: https://towardsdatascience.com/k-nearest-neighbor-python-2fccc47d2a55

# %%
"""
Source: 
https://machinelearningmastery.com/hyperparameters-for-classification-machine-learning-algorithms/
"""
# example of grid searching key hyperparametres for KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier

X = obese_df[['Ethnicity', 'Age', 'Gender', 'LOS', 'CKD_Status', 'Bleeding_Risk',
       'VTE_Risk', 'Comorbidity', 'Treatment_days', 'Apixa_10mg',
       'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg', 'Dabi_75mg',
       'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
       'Mortality', 'Emergency_visits', 'Bleeding', 'Thrombosis']]
y = obese_df[['Stroke']]
normalized_X = preprocessing.normalize(X)
standardized_X = preprocessing.scale(X)

# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1,stratify=y)

# define models and parameters
KNN_model = KNeighborsClassifier()

### fit/train model
result_knn = KNN_model.fit(X_train, y_train.values.ravel())

#pridiction
y_pred = KNN_model.predict(X_test)
#accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
namez =  ["Stroke=0", "Stroke=1"]
print(metrics.classification_report(y_test, y_pred, target_names=namez, digits=2,output_dict=False)) 

#confusion matrix
print("Confusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9976617303195635
#               precision    recall  f1-score   support
#
#     Stroke=0       1.00      1.00      1.00      1205
#     Stroke=1       0.99      0.97      0.98        78
#
#     accuracy                           1.00      1283
#    macro avg       0.99      0.99      0.99      1283
# weighted avg       1.00      1.00      1.00      1283
#
# Confusion Matrix
# [[1204    1]
#  [   2   76]]

# %% [markdown]
# ## 4. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

X = obese_df[['Ethnicity', 'Age', 'Gender', 'LOS', 'CKD_Status', 'Bleeding_Risk',
       'VTE_Risk', 'Comorbidity', 'Treatment_days', 'Apixa_10mg',
       'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg', 'Dabi_75mg',
       'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
       'Mortality', 'Emergency_visits', 'Bleeding', 'Thrombosis']]
y = obese_df[['Stroke']]

# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1,stratify=y)


# define models and parameters
model_lg = LogisticRegression()

### fit/train model
result_lg = model_lg.fit(X_train, y_train.values.ravel())

#pridiction
y_pred = model_lg.predict(X_test)
#accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
namez =  ["Stroke=0", "Stroke=1"]
print(metrics.classification_report(y_test, y_pred, target_names=namez, digits=2,output_dict=False)) 

#confusion matrix
print("Confusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.970381917381138
#               precision    recall  f1-score   support
#
#     Stroke=0       0.97      1.00      0.98      1205
#     Stroke=1       1.00      0.51      0.68        78
#
#     accuracy                           0.97      1283
#    macro avg       0.98      0.76      0.83      1283
# weighted avg       0.97      0.97      0.97      1283
#
# Confusion Matrix
# [[1205    0]
#  [  38   40]]
# D:\Ayub_Ansari_PhD_Experiments\Dr_Shahzad_Colab\ve_dr_shahzad\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## 5. Gradient Bossting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

X = obese_df[['Ethnicity', 'Age', 'Gender', 'LOS', 'CKD_Status', 'Bleeding_Risk',
       'VTE_Risk', 'Comorbidity', 'Treatment_days', 'Apixa_10mg',
       'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg', 'Dabi_75mg',
       'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
       'Mortality', 'Emergency_visits', 'Bleeding', 'Thrombosis']]
y = obese_df[['Stroke']]
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1,stratify=y)

# define models and parameters
model_GBC = GradientBoostingClassifier()

### fit/train model
result_GBC = model_GBC.fit(X_train, y_train.values.ravel())

#pridiction
y_pred = model_GBC.predict(X_test)
#accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
namez =  ["Stroke=0", "Stroke=1"]
print(metrics.classification_report(y_test, y_pred, target_names=namez, digits=2,output_dict=False)) 

#confusion matrix
print("Confusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#     Stroke=0       1.00      1.00      1.00      1205
#     Stroke=1       1.00      1.00      1.00        78
#
#     accuracy                           1.00      1283
#    macro avg       1.00      1.00      1.00      1283
# weighted avg       1.00      1.00      1.00      1283
#
# Confusion Matrix
# [[1205    0]
#  [   0   78]]

# %% [markdown]
# ## 6. Support Vector Machine

# %%
from sklearn.svm import SVC

X = obese_df[['Ethnicity', 'Age', 'Gender', 'LOS', 'CKD_Status', 'Bleeding_Risk',
       'VTE_Risk', 'Comorbidity', 'Treatment_days', 'Apixa_10mg',
       'Apixa_2.5mg', 'Apixa_5mg', 'Dabi_110mg', 'Dabi_150mg', 'Dabi_75mg',
       'Edoxa_30mg', 'Edoxa_60mg', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
       'Mortality', 'Emergency_visits', 'Bleeding', 'Thrombosis']]
y = obese_df[['Stroke']]
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=1,stratify=y)

# define model and parameters
model_SVM = SVC()

#fit/train model
model_SVM.fit(X_train, y_train.values.ravel())
#### Model prediction
y_predict = model_SVM.predict(X_test)

#accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
namez =  ["Stroke=0", "Stroke=1"]
print(metrics.classification_report(y_test, y_pred, target_names=namez, digits=2,output_dict=False)) 

#confusion matrix
print("Confusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#     Stroke=0       1.00      1.00      1.00      1205
#     Stroke=1       1.00      1.00      1.00        78
#
#     accuracy                           1.00      1283
#    macro avg       1.00      1.00      1.00      1283
# weighted avg       1.00      1.00      1.00      1283
#
# Confusion Matrix
# [[1205    0]
#  [   0   78]]
