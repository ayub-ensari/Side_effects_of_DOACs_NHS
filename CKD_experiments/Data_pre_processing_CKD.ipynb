# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn

# %%
df = pd.read_excel("CKD_ML_061022.xlsx")

# %%
df.head(10)
# Out:
#    Age  EG_White  EG_BAME  EG_Other  Male  Female  Comorbidity  Bleeding_Risk  \
# 0   83         1        2         2     1       2            1              2
# 1   83         1        2         2     1       2            1              2
# 2   83         1        2         2     1       2            1              2
# 3   83         1        2         2     1       2            1              2
# 4   83         1        2         2     1       2            1              2
# 5   83         1        2         2     1       2            1              2
# 6   83         1        2         2     1       2            1              2
# 7   83         1        2         2     1       2            1              2
# 8   83         1        2         2     1       2            1              2
# 9   83         1        2         2     1       2            1              2
#
#    VTE_Risk    BMI  ...  Stage3a_CKD  Stage3b_CKD  Stage4_CKD  Stage5_CKD  \
# ...

# %% [markdown]
# > The encoding of various attrivutes was done in SPSS. The 2 should be 0. Lets replace 2 woth 0.

# %%
df.EG_White = df.EG_White.replace(2,0)
df.EG_BAME = df.EG_BAME.replace(2,0)
df.EG_Other = df.EG_Other.replace(2,0)
df.Male = df.Male.replace(2,0)
#### Drop female coulmn and rename male column as gneder with 1 = male, 0=female
df = df.drop(['Female'], axis=1)
df = df.rename({'Male': 'Gender'}, axis=1)

df.Comorbidity = df.Comorbidity.replace(2,0)
df.Bleeding_Risk = df.Bleeding_Risk.replace(2,0)
df.VTE_Risk = df.VTE_Risk.replace(2,0)
df.Apixa_2_5mg = df.Apixa_2_5mg.replace(2,0)
df.Apixa_5mg = df.Apixa_5mg.replace(2,0)
df.Apixa_10mg = df.Apixa_10mg.replace(2,0)
df.Dabi_75mg = df.Dabi_75mg.replace(2,0)
df.Dabi_110mg = df.Dabi_110mg.replace(2,0)
df.Dabi_150mg = df.Dabi_150mg.replace(2,0)
df.Edoxa_30mg = df.Edoxa_30mg.replace(2,0)
df.Edoxa_60 = df.Edoxa_60.replace(2,0)
df.Riva_10mg = df.Riva_10mg.replace(2,0)
df.Riva_15mg = df.Riva_15mg.replace(2,0)
df.Riva_20mg = df.Riva_20mg.replace(2,0)
df.Normal_Renal_Function = df.Normal_Renal_Function.replace(2,0)
df.Stage3a_CKD = df.Stage3a_CKD.replace(2,0)
df.Stage3b_CKD = df.Stage3b_CKD.replace(2,0)
df.Stage4_CKD = df.Stage4_CKD.replace(2,0)
df.Stage5_CKD = df.Stage5_CKD.replace(2,0)

# %%
df.head(10)
# Out:
#    Age  EG_White  EG_BAME  EG_Other  Gender  Comorbidity  Bleeding_Risk  \
# 0   83         1        0         0       1            1              0
# 1   83         1        0         0       1            1              0
# 2   83         1        0         0       1            1              0
# 3   83         1        0         0       1            1              0
# 4   83         1        0         0       1            1              0
# 5   83         1        0         0       1            1              0
# 6   83         1        0         0       1            1              0
# 7   83         1        0         0       1            1              0
# 8   83         1        0         0       1            1              0
# 9   83         1        0         0       1            1              0
#
#    VTE_Risk    BMI  Treatment_days  ...  Stage3a_CKD  Stage3b_CKD  Stage4_CKD  \
# 0         1  17.18              72  ...            0            0           0
# ...

# %%
df.columns
# Out:
# Index(['Age', 'EG_White', 'EG_BAME', 'EG_Other', 'Gender', 'Comorbidity',
#        'Bleeding_Risk', 'VTE_Risk', 'BMI', 'Treatment_days', 'Apixa_2_5mg',
#        'Apixa_5mg', 'Apixa_10mg', 'Dabi_75mg', 'Dabi_110mg', 'Dabi_150mg',
#        'Edoxa_30mg', 'Edoxa_60', 'Riva_10mg', 'Riva_15mg', 'Riva_20mg',
#        'Normal_Renal_Function', 'Stage3a_CKD', 'Stage3b_CKD', 'Stage4_CKD',
#        'Stage5_CKD', 'Mortality', 'Bleeding', 'Stroke', 'Thrombosis',
#        'Emergency_Adm', 'LoS'],
#       dtype='object')

# %%
df.shape
# Out:
# (97413, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97413 entries, 0 to 97412
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    97413 non-null  int64
#  1   EG_White               97413 non-null  int64
#  2   EG_BAME                97413 non-null  int64
#  3   EG_Other               97413 non-null  int64
#  4   Gender                 97413 non-null  int64
#  5   Comorbidity            97413 non-null  int64
#  6   Bleeding_Risk          97413 non-null  int64
#  7   VTE_Risk               97413 non-null  int64
#  8   BMI                    97413 non-null  float64
#  9   Treatment_days         97413 non-null  int64
#  10  Apixa_2_5mg            97413 non-null  int64
#  11  Apixa_5mg              97413 non-null  int64
#  12  Apixa_10mg             97413 non-null  int64
#  13  Dabi_75mg              97413 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 Age      EG_White       EG_BAME      EG_Other        Gender  \
# count  97413.000000  97413.000000  97413.000000  97413.000000  97413.000000
# mean      78.808301      0.927597      0.031372      0.041031      0.475152
# std       11.515017      0.259155      0.174321      0.198364      0.499385
# min       19.000000      0.000000      0.000000      0.000000      0.000000
# 25%       74.000000      1.000000      0.000000      0.000000      0.000000
# 50%       81.000000      1.000000      0.000000      0.000000      0.000000
# 75%       87.000000      1.000000      0.000000      0.000000      1.000000
# max      103.000000      1.000000      1.000000      1.000000      1.000000
#
#         Comorbidity  Bleeding_Risk      VTE_Risk           BMI  \
# count  97413.000000   97413.000000  97413.000000  97413.000000
# mean       0.842105       0.717420      0.994898     27.166205
# std        0.364644       0.450256      0.071246      7.172186
# ...

# %%
df.to_csv("CKD_ML_Final.csv", index = False)
